# %%
## Read the three files into python as dataframes

#Show the DataFrame's shape.

#Standardize header names.

#Rearrange the columns in the dataframe as needed

#Concatenate the three dataframes

#Which columns are numerical?

#Which columns are categorical?

#Understand the meaning of all columns

#Perform the data cleaning operations mentioned so far in class

    #Delete the column education and the number of open complaints from the dataframe.
    #Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
    #Check for duplicate rows in the data and remove if any.
    #Filter out the data for customers who have an income of 0 or less.

# %%
import pandas as pd 
import numpy as np

# %%
data_file1 = pd.read_csv(r"C:\Users\pedro\Desktop\ironhack\LAB_costumer_analysis_round1\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv")
data_file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data_file2 = pd.read_csv(r"C:\Users\pedro\Desktop\ironhack\LAB_costumer_analysis_round1\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv")
data_file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
data_file3 = pd.read_csv(r"C:\Users\pedro\Desktop\ironhack\LAB_costumer_analysis_round1\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv")
data_file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
data_file1.shape
data_file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data_file2.shape
data_file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
data_file3.shape
data_file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
column_file1 = []

for i in range(len(data_file1.columns)):
    column_file1.append(data_file1.columns[i].lower().replace(' ', '_'))
    
data_file1.columns = column_file1
data_file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
column_file2 = []

for i in range(len(data_file2.columns)):
    column_file2.append(data_file2.columns[i].lower().replace(' ', '_'))
    
data_file2.columns = column_file2
data_file2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
column_file3 = []

for i in range(len(data_file3.columns)):
    column_file3.append(data_file3.columns[i].lower().replace(' ', '_'))
    
data_file3.columns = column_file3
data_file3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#rename the 2 diferente columns in dataframe 1 and dataframe2 to be named as 'state' like the the dataframe3
data_file1 = data_file1.rename(columns={ 'st':'state'})
data_file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data_file2 = data_file2.rename(columns={ 'st':'state'})
data_file2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
#rearranging the data files to concatenate them 
data_file2=data_file2[data_file1.columns]
data_file3=data_file3[data_file1.columns]

# %%
#concatenate the dataframes
data_concatenated = pd.concat([data_file1, data_file2, data_file3], axis=0)
data_concatenated


#after checking the number of columns i know i did the concatenation
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
#check the data types of the concatenated dfs
data_concatenated.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
#checking the categorical and numerical types of each column in the DF
numerical_data=data_concatenated.select_dtypes(np.number)
numerical_data
# Out:
#        income  monthly_premium_auto  total_claim_amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
categorical_data = data_concatenated.select_dtypes(object)
categorical_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value number_of_open_complaints     policy_type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
#costumer column identifies the costumer
#state provaides the location of the costumer
#gender, well, the gender male of female, or non specified
#education - the degree of education
#customer lifetime value
#income, should be the earnings of a year for each costumer
#monthly premium auto - the amount paid monthly by each customer
#number of open complaints that customer has 
#policy type, what kind of contract the costumer has, personal or corporate
#vehicle class what kind of car it is 
#total claim amount, the total amount of all customer charges

# %%
data_concatenated = data_concatenated.drop(['education'], axis = 1) # If you want to delete more than 1 column use double brackets [[]]
data_concatenated
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
#eliminating the complaints
data_concatenated = data_concatenated.drop(['number_of_open_complaints'], axis = 1) # If you want to delete more than 1 column use double brackets [[]]
data_concatenated
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data_concatenated['customer_lifetime_value'] = data_concatenated['customer_lifetime_value'].str.replace('%','')

# %%
data_concatenated['customer_lifetime_value'] = pd.to_numeric(data_concatenated['customer_lifetime_value'])
data_concatenated
#ity is giving me this error and i've tried in very different ways.
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                697953.59      0.0
# 2     AI49188      Nevada      F               1288743.17  48767.0
# 3     WW63253  California      M                764586.18      0.0
# 4     GA49547  Washington      M                536307.65  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
data_concatenated.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
data_concatenated['customer_lifetime_value']*100

data_concatenated
#this is not giving me the results because i couldnt change the customer_lifetime_value to a flot or integer.
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                697953.59      0.0
# 2     AI49188      Nevada      F               1288743.17  48767.0
# 3     WW63253  California      M                764586.18      0.0
# 4     GA49547  Washington      M                536307.65  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
#Check for duplicate rows in the data and remove if any duplicates

data_concatenated.duplicated()

data_concatenated.drop_duplicates()

data_concatenated
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                697953.59      0.0
# 2     AI49188      Nevada      F               1288743.17  48767.0
# 3     WW63253  California      M                764586.18      0.0
# 4     GA49547  Washington      M                536307.65  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
condition = data_concatenated['income'] <= 0
data_concatenated[condition]
# Out:
#        index customer       state gender customer_lifetime_value  income  \
# 0          0  RB50392  Washington    NaN                     nan     0.0
# 1          1  QZ44356     Arizona      F              697953.59%     0.0
# 3          3  WW63253  California      M              764586.18%     0.0
# 7          7  CF85061     Arizona      M              721610.03%     0.0
# 10        10  SX51350  California      M              473899.20%     0.0
# ...      ...      ...         ...    ...                     ...     ...
# 12063   7059  WZ45103  California      F             5678.050167     0.0
# 12065   7061  RX91025  California      M               19872.262     0.0
# 12066   7062  AC13887  California      M             4628.995325     0.0
# 12071   7067  TD14365  California      M             8163.890428     0.0
# 12073   7069  Y167826  California      M             2611.836866     0.0
#
#        monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# ...
