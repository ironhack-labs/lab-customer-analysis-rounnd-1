# %%
import pandas as pd
import numpy as np

# %%
lab1 = pd.read_csv('file1.csv')

# %%
lab2 = pd.read_csv('file2.csv')

# %%
lab3 = pd.read_csv('file3.csv')

# %%
data.reindex
# Out:
# <bound method DataFrame.reindex of      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# ...

# %%
data = pd.concat([lab1,lab2,lab3])

# %%
data.shape
# Out:
# (12074, 13)

# %%
data.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount', 'State',
#        'Gender'],
#       dtype='object')

# %%
colunas = []
for column in range(len(data.columns)):
    colunas.append(data.columns[column].lower())
data.columns = colunas

# %%
data.head()
# Out:
#   customer          st gender customer lifetime value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      F              697953.59%      0.0
# 2  AI49188      Nevada      F             1288743.17%  48767.0
# 3  WW63253  California      M              764586.18%      0.0
# 4  GA49547  Washington      M              536307.65%  36357.0
#
#    monthly premium auto     policy type  vehicle class  total claim amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
#
#   state gender     revenue        data
# 0   NaN    NaN         NaN         NaN
# 1   NaN    NaN   697953.59   697953.59
# ...

# %%
data._get_numeric_data()
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
data.select_dtypes('object')
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      customer lifetime value number of open complaints     policy type  \
# 0                        NaN                    1/0/00   Personal Auto
# 1                 697953.59%                    1/0/00   Personal Auto
# 2                1288743.17%                    1/0/00   Personal Auto
# ...

# %%
data.iloc[1:13]
# Out:
#    customer          st gender customer lifetime value   income  \
# 1   QZ44356     Arizona      F              697953.59%      0.0
# 2   AI49188      Nevada      F             1288743.17%  48767.0
# 3   WW63253  California      M              764586.18%      0.0
# 4   GA49547  Washington      M              536307.65%  36357.0
# 5   OC83172      Oregon      F              825629.78%  62902.0
# 6   XZ87318      Oregon      F              538089.86%  55350.0
# 7   CF85061     Arizona      M              721610.03%      0.0
# 8   DY87989      Oregon      M             2412750.40%  14072.0
# 9   BQ94931      Oregon      F              738817.81%  28812.0
# 10  SX51350  California      M              473899.20%      0.0
# 11  VQ65197  California    NaN              819719.71%      0.0
# 12  DP39365  California    NaN              879879.70%  77026.0
#
#     monthly premium auto     policy type  vehicle class  total claim amount  \
# ...

# %%
data.drop(['education','number of open complaints'],axis=1,inplace=True)

# %%
data
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN    NaN             23405.98798  71941.0
# 7066  PK87824         NaN    NaN             3096.511217  21604.0
# 7067  TD14365         NaN    NaN             8163.890428      0.0
# 7068  UP19263         NaN    NaN             7524.442436  21941.0
# 7069  Y167826         NaN    NaN             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['customer lifetime value'].str.rstrip("%").astype("float") * 100
# Out:
# 0               NaN
# 1        69795359.0
# 2       128874317.0
# 3        76458618.0
# 4        53630765.0
#            ...
# 7065            NaN
# 7066            NaN
# 7067            NaN
# 7068            NaN
# 7069            NaN
# Name: customer lifetime value, Length: 12074, dtype: float64

# %%
data.drop_duplicates()
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN    NaN              Bachelor
# 7066  PK87824         NaN    NaN               College
# 7067  TD14365         NaN    NaN              Bachelor
# 7068  UP19263         NaN    NaN               College
# 7069  Y167826         NaN    NaN               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data[data['income'] <= 0]
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 7     CF85061     Arizona      M                Master
# 10    SX51350  California      M               College
# ...       ...         ...    ...                   ...
# 7059  WZ45103         NaN    NaN              Bachelor
# 7061  RX91025         NaN    NaN  High School or Below
# 7062  AC13887         NaN    NaN              Bachelor
# 7067  TD14365         NaN    NaN              Bachelor
# 7069  Y167826         NaN    NaN               College
#
#      customer lifetime value  income  monthly premium auto  \
# 0                        NaN     0.0                1000.0
# 1                 697953.59%     0.0                  94.0
# 3                 764586.18%     0.0                 106.0
# 7                 721610.03%     0.0                 101.0
# ...
