# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')

# %%
file2 = pd.read_csv('file2.csv')

# %%
file3 = pd.read_csv('file3.csv')

# %%
df1 = pd.read_csv("file1.csv")

# %%
df2 = pd.read_csv("file2.csv")

# %%
df3 = pd.read_csv("file3.csv")

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
for col in df1.columns:
    print(col)
# Out:
# Customer
# ST
# GENDER
# Education
# Customer Lifetime Value
# Income
# Monthly Premium Auto
# Number of Open Complaints
# Policy Type
# Vehicle Class
# Total Claim Amount

# %%
cols = []
for column in range (len(df1.columns)):
    cols.append(df1.columns[column].lower())
df1.columns = cols

# %%
for col in df1.columns:
    print(col)
# Out:
# customer
# st
# gender
# education
# customer lifetime value
# income
# monthly premium auto
# number of open complaints
# policy type
# vehicle class
# total claim amount

# %%
for col in df2.columns:
    print(col)
# Out:
# Customer
# ST
# GENDER
# Education
# Customer Lifetime Value
# Income
# Monthly Premium Auto
# Number of Open Complaints
# Total Claim Amount
# Policy Type
# Vehicle Class

# %%
cols = []
for column in range (len(df2.columns)):
    cols.append(df2.columns[column].lower())
df2.columns = cols

# %%
for col in df2.columns:
    print(col)
# Out:
# customer
# st
# gender
# education
# customer lifetime value
# income
# monthly premium auto
# number of open complaints
# total claim amount
# policy type
# vehicle class

# %%
cols = []
for column in range (len(df3.columns)):
    cols.append(df3.columns[column].lower())
df3.columns = cols

# %%
for col in df3.columns:
    print(col)
# Out:
# customer
# state
# customer lifetime value
# education
# gender
# income
# monthly premium auto
# number of open complaints
# policy type
# total claim amount
# vehicle class

# %%
display(df1)
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1 = df1[df1["customer lifetime value"].notna()]

# %%
df1["customer lifetime value"] = pd.to_numeric(df1["customer lifetime value"].str.replace("%",""))

# %%
df1["customer lifetime value"] = df1["customer lifetime value"] *100

# %%
display(df1)
# Out:
#      customer          st gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 1066  TM65736      Oregon      M                Master
# 1067  VJ51327        Cali      F  High School or Below
# 1068  GS98873     Arizona      F              Bachelor
# 1069  CW49887  California      F                Master
# 1070  MY31220  California      F               College
#
#       customer lifetime value   income  monthly premium auto  \
# 1                  69795359.0      0.0                  94.0
# 2                 128874317.0  48767.0                 108.0
# 3                  76458618.0      0.0                 106.0
# ...

# %%
df2 = df2[df2["customer lifetime value"].notna()]

# %%
df2["customer lifetime value"] = pd.to_numeric(df2["customer lifetime value"].str.replace("%",""))

# %%
df2["customer lifetime value"] = df2["customer lifetime value"] *100

# %%
display(df2)
# Out:
#     customer          st gender education  customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor               32391247.0   16061
# 1    CW49887  California      F    Master               46268011.0   79487
# 2    MY31220  California      F   College               89970402.0   54230
# 3    UH35128      Oregon      F   College              258070630.0   71210
# 4    WH52799     Arizona      F   College               38081221.0   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master               84714175.0   63513
# 992  BS91566     Arizona      F   College               54312191.0   58161
# 993  IL40123      Nevada      F   College               56896441.0   83640
# 994  MY32149  California      F    Master               36867238.0       0
# 995  SA91515  California      M  Bachelor               39925839.0       0
#
# ...

# %%
df3.dtypes
# Out:
# customer                      object
# state                         object
# customer lifetime value      float64
# education                     object
# gender                        object
# income                         int64
# monthly premium auto           int64
# number of open complaints      int64
# policy type                   object
# total claim amount           float64
# vehicle class                 object
# dtype: object

# %%
df3 = df3[df3["customer lifetime value"].notna()]

# %%
df3["customer lifetime value"] = df3["customer lifetime value"] *100

# %%
display(df3)
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington             3.479138e+05  High School or Below
# 1     TB86706     Arizona             2.502637e+05                Master
# 2     ZL73902      Nevada             3.265156e+05              Bachelor
# 3     KX23516  California             4.455843e+05  High School or Below
# 4     FN77294  California             7.704958e+05  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             2.340599e+06              Bachelor
# 7066  PK87824  California             3.096511e+05               College
# 7067  TD14365  California             8.163890e+05              Bachelor
# 7068  UP19263  California             7.524442e+05               College
# 7069  Y167826  California             2.611837e+05               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
data = pd.concat([df1,df2,df3])

# %%
display(data)
# Out:
#      customer          st gender             education  \
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# 5     OC83172      Oregon      F              Bachelor
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#       customer lifetime value   income  monthly premium auto  \
# 1                6.979536e+07      0.0                  94.0
# 2                1.288743e+08  48767.0                 108.0
# 3                7.645862e+07      0.0                 106.0
# ...

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value      float64
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# state                         object
# dtype: object

# %%
data = data.drop(['education', 'number of open complaints'],axis=1)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (9127, 10)

# %%
filtered = data[data['income']<=0]

# %%
display(filtered)
# Out:
#      customer          st gender  customer lifetime value  income  \
# 1     QZ44356     Arizona      F             6.979536e+07     0.0
# 3     WW63253  California      M             7.645862e+07     0.0
# 7     CF85061     Arizona      M             7.216100e+07     0.0
# 10    SX51350  California      M             4.738992e+07     0.0
# 11    VQ65197  California    NaN             8.197197e+07     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103         NaN      F             5.678050e+05     0.0
# 7061  RX91025         NaN      M             1.987226e+06     0.0
# 7062  AC13887         NaN      M             4.628995e+05     0.0
# 7067  TD14365         NaN      M             8.163890e+05     0.0
# 7069  Y167826         NaN      M             2.611837e+05     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# 1                     94.0   Personal Auto  Four-Door Car         1131.464935
# ...
