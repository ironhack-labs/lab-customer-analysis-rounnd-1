# %%
import pandas as pd
import numpy as np

# %%
file3 = pd.read_csv('file3.csv')

# %%
file3.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file4 = pd.read_csv('file4.csv')

# %%
file4.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
file3.head()
# Out:
#    CONTROLN      STATE GENDER   HV1  IC1  IC4  HVP1    IC5  POBC1  POBC2  IC2  \
# 0    119966         TX      F   321  225  281     0   9372      3     68  264
# 1    152470         CA      F  5725  610  807    97  53158     13     22  763
# 2     48527         AL   Male   931  407  496     0  17743      0     65  502
# 3    171528         CA      F  1895  317  471    46  17431     10     62  389
# 4     50122  Tennessee      F   715  318  370     2  12416      0     75  340
#
#    IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  243   8.058824      0  3212     T3      11.0
# 1  698  23.727273      0     0     S1      45.0
# 2  439   4.416667      2     0     R3       3.0
# 3  405   6.705882      0  5501     R2       5.0
# 4  352   9.250000      2     0     T1      10.0

# %%
file3.rename(columns={'CONTROLN':'ID','HV1':'MEDIAN_HOME','IC1':'INCOME'}, inplace=True)

# %%
file4.rename(columns={'CONTROLN':'ID','HV1':'MEDIAN_HOME','IC1':'INCOME'}, inplace=True)

# %%
file4
# Out:
#           ID STATE GENDER MEDIAN_HOME  INCOME  IC4  HVP1    IC5  POBC1  POBC2  \
# 0     186307    CA      M     AAA1229     345  438     3  15915      2     58
# 1      34174    WV      F         529     198  291     0  10816      0     80
# 2     101388    MO      M         526     340  342     0   9687      0     89
# 3     159472    CA      F         621     231  279     0   6184     43     41
# 4     179143    WA   male        1688     496  564    35  22963      2     63
# ...      ...   ...    ...         ...     ...  ...   ...    ...    ...    ...
# 1001   41537    FL      F         742     396  470     0  15356      7     37
# 1002    4881    FL      M         599     100  423     4  11670     10     27
# 1003   66358    ND      M         593     258  299     0  10186      1     70
# 1004    2231    WI   male         564     217  397     0  12315      0     96
# 1005   68534    MI      M         651     431  505     0  14845      7     77
#
# ...

# %%
data2 = pd.concat([file3,file4])

# %%
len(file3) + len(file4) == len(data2)
# Out:
# True

# %%
cols = []
for column in range(len(data2.columns)):
    cols.append(data2.columns[column].lower())
data2.columns = cols

# %%
data2.head()
# Out:
#        id      state gender median_home  income  ic4  hvp1    ic5  pobc1  \
# 0  119966         TX      F         321     225  281     0   9372      3
# 1  152470         CA      F        5725     610  807    97  53158     13
# 2   48527         AL   Male         931     407  496     0  17743      0
# 3  171528         CA      F        1895     317  471    46  17431     10
# 4   50122  Tennessee      F         715     318  370     2  12416      0
#
#    pobc2  ic2  ic3    avggift  tcode   dob domain  target_d
# 0     68  264  243   8.058824      0  3212     T3      11.0
# 1     22  763  698  23.727273      0     0     S1      45.0
# 2     65  502  439   4.416667      2     0     R3       3.0
# 3     62  389  405   6.705882      0  5501     R2       5.0
# 4     75  340  352   9.250000      2     0     T1      10.0

# %%
data2.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home', 'income', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %%
data2.shape
# Out:
# (2006, 17)

# %%
data2.drop(columns = {'dob','domain'})
# Out:
#           id      state gender median_home  income  ic4  hvp1    ic5  pobc1  \
# 0     119966         TX      F         321     225  281     0   9372      3
# 1     152470         CA      F        5725     610  807    97  53158     13
# 2      48527         AL   Male         931     407  496     0  17743      0
# 3     171528         CA      F        1895     317  471    46  17431     10
# 4      50122  Tennessee      F         715     318  370     2  12416      0
# ...      ...        ...    ...         ...     ...  ...   ...    ...    ...
# 1001   41537         FL      F         742     396  470     0  15356      7
# 1002    4881         FL      M         599     100  423     4  11670     10
# 1003   66358         ND      M         593     258  299     0  10186      1
# 1004    2231         WI   male         564     217  397     0  12315      0
# 1005   68534         MI      M         651     431  505     0  14845      7
#
#       pobc2  ic2  ic3    avggift  tcode  target_d
# ...

# %%
#activity 2
data3 = pd.concat([data,data2])

# %%
len(data) + len(data2) == len(data3)
# Out:
# True

# %%
data3.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home', 'income', 'ic4', 'hvp1', 'ic5',
#        'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'tcode', 'dob', 'domain',
#        'target_d'],
#       dtype='object')

# %%
data3.shape
# Out:
# (4012, 17)

# %%
data3.head()
# Out:
#        id      state gender median_home  income  ic4  hvp1    ic5  pobc1  \
# 0  119966         TX      F         321     225  281     0   9372      3
# 1  152470         CA      F        5725     610  807    97  53158     13
# 2   48527         AL   Male         931     407  496     0  17743      0
# 3  171528         CA      F        1895     317  471    46  17431     10
# 4   50122  Tennessee      F         715     318  370     2  12416      0
#
#    pobc2  ic2  ic3    avggift  tcode   dob domain  target_d
# 0     68  264  243   8.058824      0  3212     T3      11.0
# 1     22  763  698  23.727273      0     0     S1      45.0
# 2     65  502  439   4.416667      2     0     R3       3.0
# 3     62  389  405   6.705882      0  5501     R2       5.0
# 4     75  340  352   9.250000      2     0     T1      10.0

# %%
data3.drop(columns = {'dob','domain'})
# Out:
#           id      state gender median_home  income  ic4  hvp1    ic5  pobc1  \
# 0     119966         TX      F         321     225  281     0   9372      3
# 1     152470         CA      F        5725     610  807    97  53158     13
# 2      48527         AL   Male         931     407  496     0  17743      0
# 3     171528         CA      F        1895     317  471    46  17431     10
# 4      50122  Tennessee      F         715     318  370     2  12416      0
# ...      ...        ...    ...         ...     ...  ...   ...    ...    ...
# 1001   41537         FL      F         742     396  470     0  15356      7
# 1002    4881         FL      M         599     100  423     4  11670     10
# 1003   66358         ND      M         593     258  299     0  10186      1
# 1004    2231         WI   male         564     217  397     0  12315      0
# 1005   68534         MI      M         651     431  505     0  14845      7
#
#       pobc2  ic2  ic3    avggift  tcode  target_d
# ...

# %%
data3.columns = (['id', 'state', 'gender', 'ic2', 'ic3', 'ic4', 'median_home', 'income', 'hvp1', 'ic5',
       'pobc1', 'pobc2',  'avggift', 'tcode', 'dob', 'domain',
       'target_d'])

# %%
data3.head()
# Out:
#        id      state gender   ic2  ic3  ic4  median_home  income  hvp1  ic5  \
# 0  119966         TX      F   321  225  281            0    9372     3   68
# 1  152470         CA      F  5725  610  807           97   53158    13   22
# 2   48527         AL   Male   931  407  496            0   17743     0   65
# 3  171528         CA      F  1895  317  471           46   17431    10   62
# 4   50122  Tennessee      F   715  318  370            2   12416     0   75
#
#    pobc1  pobc2    avggift  tcode   dob domain  target_d
# 0    264    243   8.058824      0  3212     T3      11.0
# 1    763    698  23.727273      0     0     S1      45.0
# 2    502    439   4.416667      2     0     R3       3.0
# 3    389    405   6.705882      0  5501     R2       5.0
# 4    340    352   9.250000      2     0     T1      10.0

# %%
filtered2 = data3[(data3['gender']=='M')&(data3['state']=='FL')]

# %%
filtered2.reset_index()
# Out:
#      index     id state gender  ic2  ic3  ic4  median_home  income  hvp1  ic5  \
# 0       30  35581    FL      M  906  296  473            3   16729     4   37
# 1       31  46358    FL      M  715  362  408            0   12806     6   28
# 2       38  41545    FL      M  658  373  436            0   14942    11   23
# 3       55  11284    FL      M  934  324  478            9   17408     4   11
# 4       59  25678    FL      M  721  302  365            2   12474     3   51
# ..     ...    ...   ...    ...  ...  ...  ...          ...     ...   ...  ...
# 133    962  36776    FL      M  653  319  379            0   12869    11   35
# 134    973   4881    FL      M  599  100  423            4   11670    10   27
# 135    992   6403    FL      M  677  311  313            0   12509     2   23
# 136    997   6443    FL      M  595  252  274            0   11132     8   11
# 137   1002   4881    FL      M  599  100  423            4   11670    10   27
#
# ...

# %%
print(data3.dtypes)
# Out:
# id               int64
# state           object
# gender          object
# ic2             object
# ic3              int64
# ic4              int64
# median_home      int64
# income           int64
# hvp1             int64
# ic5              int64
# pobc1            int64
# pobc2            int64
# avggift          int64
# tcode            int64
# dob              int64
# domain          object
# target_d       float64
# dtype: object

# %%
data3 = data3.astype({'avggift':'int'})
print(data3.dtypes)
# Out:
# id               int64
# state           object
# gender          object
# ic2             object
# ic3              int64
# ic4              int64
# median_home      int64
# income           int64
# hvp1             int64
# ic5              int64
# pobc1            int64
# pobc2            int64
# avggift          int64
# tcode            int64
# dob              int64
# domain          object
# target_d       float64
# dtype: object

# %%
filtered4 = data3[(data3['gender']=='F') & (data3['median_home']<100)]

# %%
filtered4
# Out:
#           id      state gender   ic2  ic3  ic4  median_home  income  hvp1  \
# 0     119966         TX      F   321  225  281            0    9372     3
# 1     152470         CA      F  5725  610  807           97   53158    13
# 3     171528         CA      F  1895  317  471           46   17431    10
# 4      50122  Tennessee      F   715  318  370            2   12416     0
# 5      92293         IL      F  3359  878  973           87   35266    16
# ...      ...        ...    ...   ...  ...  ...          ...     ...   ...
# 991    77441         WI      F   725  316  376            0   11623     1
# 993   117326         TX      F  1715  554  837           34   31480     3
# 996    66762         MI      F   632  279  388            2   12653     1
# 998   151175         CA      F  2707  507  537           80   16165    24
# 1001   41537         FL      F   742  396  470            0   15356     7
#
#       ic5  pobc1  pobc2  avggift  tcode   dob domain  target_d
# ...

# %%
#activity3
filtered3 = data3[(data3['gender']=='F')]

# %%
filtered3.reset_index()
# Out:
#       index      id      state gender   ic2  ic3  ic4  median_home  income  \
# 0         0  119966         TX      F   321  225  281            0    9372
# 1         1  152470         CA      F  5725  610  807           97   53158
# 2         3  171528         CA      F  1895  317  471           46   17431
# 3         4   50122  Tennessee      F   715  318  370            2   12416
# 4         5   92293         IL      F  3359  878  973           87   35266
# ...     ...     ...        ...    ...   ...  ...  ...          ...     ...
# 1963    991   77441         WI      F   725  316  376            0   11623
# 1964    993  117326         TX      F  1715  554  837           34   31480
# 1965    996   66762         MI      F   632  279  388            2   12653
# 1966    998  151175         CA      F  2707  507  537           80   16165
# 1967   1001   41537         FL      F   742  396  470            0   15356
#
# ...

# %%
filtered3.head(10)
# Out:
#         id      state gender   ic2  ic3  ic4  median_home  income  hvp1  ic5  \
# 0   119966         TX      F   321  225  281            0    9372     3   68
# 1   152470         CA      F  5725  610  807           97   53158    13   22
# 3   171528         CA      F  1895  317  471           46   17431    10   62
# 4    50122  Tennessee      F   715  318  370            2   12416     0   75
# 5    92293         IL      F  3359  878  973           87   35266    16   74
# 6    47191         AL      F   950  264  378            3   20090     6   55
# 7    89288         IL      F  1243  414  507            9   15884    18   70
# 9    30051         GA      F   359  205  292            0    9279     0   90
# 12  110789         LA      F   324  129  277            1    9585     0   91
# 14  142662         CA      F  1188  166  243            5   10014    10   34
#
#     pobc1  pobc2    avggift  tcode   dob domain  target_d
# 0     264    243   8.058824      0  3212     T3      11.0
# ...

# %%
#Reset the index of filtered2 with and without using the parameter drop=True and check the difference in the results.

# %%
filtered3[100:201]
# Out:
#          id state gender   ic2  ic3  ic4  median_home  income  hvp1  ic5  \
# 198   35908    FL      F   693  373  463            7   16854     1   24
# 201   81073    WI      F   571  243  349            0   13144     3   74
# 202   38471    FL      F  1033  471  598           25   22327     6   36
# 208   95536    IL      F   886  482  433            3   13887     0   68
# 209  103330    MO      F   915  377  492            7   16206     3   62
# ..      ...   ...    ...   ...  ...  ...          ...     ...   ...  ...
# 405  186013    AL      F   554  296  391            4   12774     1   63
# 408   95132    IL      F   512  269  357            1   12842     1   73
# 409  130926    CO      F  1175  517  599            8   18850     2   38
# 413  114912    OK      F   622  306  345            0   10625     0   64
# 414  164651    CA      F  2208  313  411           71   14497    25   46
#
#      pobc1  pobc2    avggift  tcode   dob domain  target_d
# ...

# %%
filtered3.iloc[1:101]
# Out:
#          id      state gender   ic2  ic3  ic4  median_home  income  hvp1  ic5  \
# 1    152470         CA      F  5725  610  807           97   53158    13   22
# 3    171528         CA      F  1895  317  471           46   17431    10   62
# 4     50122  Tennessee      F   715  318  370            2   12416     0   75
# 5     92293         IL      F  3359  878  973           87   35266    16   74
# 6     47191         AL      F   950  264  378            3   20090     6   55
# ..      ...        ...    ...   ...  ...  ...          ...     ...   ...  ...
# 188   42686         FL      F   824  263  352            3   13532     8   13
# 190  116608         TX      F   570  226  301            2   10637     1   76
# 193  109450         LA      F   590  252  329            0   11072     0   77
# 194  102741         MO      F   238  176  287            0   10253     0   82
# 198   35908         FL      F   693  373  463            7   16854     1   24
#
# ...

# %%
filtered3.iloc[1:101,1:6]
# Out:
#          state gender   ic2  ic3  ic4
# 1           CA      F  5725  610  807
# 3           CA      F  1895  317  471
# 4    Tennessee      F   715  318  370
# 5           IL      F  3359  878  973
# 6           AL      F   950  264  378
# ..         ...    ...   ...  ...  ...
# 188         FL      F   824  263  352
# 190         TX      F   570  226  301
# 193         LA      F   590  252  329
# 194         MO      F   238  176  287
# 198         FL      F   693  373  463
#
# [100 rows x 5 columns]

# %%
print(data.dtypes)
# Out:
# id               int64
# state           object
# gender          object
# median_home     object
# income           int64
# ic4              int64
# hvp1             int64
# ic5              int64
# pobc1            int64
# pobc2            int64
# ic2              int64
# ic3              int64
# avggift        float64
# tcode            int64
# dob              int64
# domain          object
# target_d       float64
# dtype: object

# %%
data._get_numeric_data()
# Out:
#           id  income  ic4  hvp1    ic5  pobc1  pobc2  ic2  ic3    avggift  \
# 0     119966     225  281     0   9372      3     68  264  243   8.058824
# 1     152470     610  807    97  53158     13     22  763  698  23.727273
# 2      48527     407  496     0  17743      0     65  502  439   4.416667
# 3     171528     317  471    46  17431     10     62  389  405   6.705882
# 4      50122     318  370     2  12416      0     75  340  352   9.250000
# ...      ...     ...  ...   ...    ...    ...    ...  ...  ...        ...
# 1001   41537     396  470     0  15356      7     37  424  450  14.285714
# 1002    4881     100  423     4  11670     10     27  406  200   9.230769
# 1003   66358     258  299     0  10186      1     70  298  274   5.266667
# 1004    2231     217  397     0  12315      0     96  386  295  11.400000
# 1005   68534     431  505     0  14845      7     77  451  455   7.428571
#
#       tcode   dob  target_d
# 0         0  3212      11.0
# ...

# %%
data.select_dtypes('object')
# Out:
#           state gender median_home domain
# 0            TX      F         321     T3
# 1            CA      F        5725     S1
# 2            AL   Male         931     R3
# 3            CA      F        1895     R2
# 4     Tennessee      F         715     T1
# ...         ...    ...         ...    ...
# 1001         FL      F         742     S2
# 1002         FL      M         599     C1
# 1003         ND      M         593     S2
# 1004         WI   male         564     T2
# 1005         MI      M         651     S2
#
# [2006 rows x 4 columns]

# %%
pd.to_numeric(data['median_home'], errors='coerce')
# Out:
# 0        321.0
# 1       5725.0
# 2        931.0
# 3       1895.0
# 4        715.0
#          ...
# 1001     742.0
# 1002     599.0
# 1003     593.0
# 1004     564.0
# 1005     651.0
# Name: median_home, Length: 2006, dtype: float64

# %%
data.drop_duplicates(subset=['state','gender','ic2','ic3'])
# Out:
#           id      state gender median_home  income  ic4  hvp1    ic5  pobc1  \
# 0     119966         TX      F         321     225  281     0   9372      3
# 1     152470         CA      F        5725     610  807    97  53158     13
# 2      48527         AL   Male         931     407  496     0  17743      0
# 3     171528         CA      F        1895     317  471    46  17431     10
# 4      50122  Tennessee      F         715     318  370     2  12416      0
# ...      ...        ...    ...         ...     ...  ...   ...    ...    ...
# 996    66762         MI      F         632     279  388     2  12653      1
# 997     6443         FL      M         595     252  274     0  11132      8
# 998   151175         CA      F        2707     507  537    80  16165     24
# 999   151504         CA      M        2666     535  653    63  24745     22
# 1000   74303         MI      M         444     225  299     3  10088      1
#
# ...
