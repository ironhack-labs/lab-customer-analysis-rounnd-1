# %%
import pandas as pd
import numpy as np

# %%
file1=pd.read_csv('file1.csv')

# %%
file2=pd.read_csv('file2.csv')

# %%
file3=pd.read_csv('file3.csv')

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
file_1= []
for column in range(len(file1.columns)):
    file_1.append(file1.columns[column].lower())
file1.columns = file_1

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file_2= []
for column in range(len(file1.columns)):
    file_2.append(file2.columns[column].lower())
file2.columns = file_2

# %%
file_3= []
for column in range(len(file1.columns)):
    file_3.append(file3.columns[column].lower())
file3.columns = file_3

# %%
file1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'vehicle class', 'total claim amount'],
#       dtype='object')

# %%
file2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer lifetime value',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'total claim amount', 'policy type', 'vehicle class'],
#       dtype='object')

# %%
file3.columns
# Out:
# Index(['customer', 'state', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file3= file3.rename(columns={'state':'st'})

# %%
file3.columns
# Out:
# Index(['customer', 'st', 'customer lifetime value', 'education', 'gender',
#        'income', 'monthly premium auto', 'number of open complaints',
#        'policy type', 'total claim amount', 'vehicle class'],
#       dtype='object')

# %%
file1=file1[['customer', 'gender', 'st' , 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class','education', 'total claim amount']]

# %%
file1
# Out:
#      customer gender          st customer lifetime value   income  \
# 0     RB50392    NaN  Washington                     NaN      0.0
# 1     QZ44356      F     Arizona              697953.59%      0.0
# 2     AI49188      F      Nevada             1288743.17%  48767.0
# 3     WW63253      M  California              764586.18%      0.0
# 4     GA49547      M  Washington              536307.65%  36357.0
# ...       ...    ...         ...                     ...      ...
# 4003      NaN    NaN         NaN                     NaN      NaN
# 4004      NaN    NaN         NaN                     NaN      NaN
# 4005      NaN    NaN         NaN                     NaN      NaN
# 4006      NaN    NaN         NaN                     NaN      NaN
# 4007      NaN    NaN         NaN                     NaN      NaN
#
#       monthly premium auto number of open complaints     policy type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
file2=file2[['customer', 'gender', 'st' , 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class','education', 'total claim amount']]

# %%
file2
# Out:
#     customer gender          st customer lifetime value  income  \
# 0    GS98873      F     Arizona              323912.47%   16061
# 1    CW49887      F  California              462680.11%   79487
# 2    MY31220      F  California              899704.02%   54230
# 3    UH35128      F      Oregon             2580706.30%   71210
# 4    WH52799      F     Arizona              380812.21%   94903
# ..       ...    ...         ...                     ...     ...
# 991  HV85198      M     Arizona              847141.75%   63513
# 992  BS91566      F     Arizona              543121.91%   58161
# 993  IL40123      F      Nevada              568964.41%   83640
# 994  MY32149      F  California              368672.38%       0
# 995  SA91515      M  California              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# 0                      88                    1/0/00   Personal Auto
# ...

# %%
file3=file3[['customer', 'gender', 'st' , 'customer lifetime value',
       'income', 'monthly premium auto', 'number of open complaints',
       'policy type', 'vehicle class','education', 'total claim amount']]

# %%
file3
# Out:
#      customer gender          st  customer lifetime value  income  \
# 0     SA25987      M  Washington              3479.137523       0
# 1     TB86706      M     Arizona              2502.637401       0
# 2     ZL73902      F      Nevada              3265.156348   25820
# 3     KX23516      F  California              4455.843406       0
# 4     FN77294      M  California              7704.958480   30366
# ...       ...    ...         ...                      ...     ...
# 7065  LA72316      M  California             23405.987980   71941
# 7066  PK87824      F  California              3096.511217   21604
# 7067  TD14365      M  California              8163.890428       0
# 7068  UP19263      M  California              7524.442436   21941
# 7069  Y167826      M  California              2611.836866       0
#
#       monthly premium auto  number of open complaints     policy type  \
# 0                      104                          0   Personal Auto
# ...

# %%
data = pd.concat([file1,file2,file3])

# %%
data._get_numeric_data()
# Out:
#        income  monthly premium auto  total claim amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
data.select_dtypes('object')
# Out:
#      customer gender          st customer lifetime value  \
# 0     RB50392    NaN  Washington                     NaN
# 1     QZ44356      F     Arizona              697953.59%
# 2     AI49188      F      Nevada             1288743.17%
# 3     WW63253      M  California              764586.18%
# 4     GA49547      M  Washington              536307.65%
# ...       ...    ...         ...                     ...
# 7065  LA72316      M  California             23405.98798
# 7066  PK87824      F  California             3096.511217
# 7067  TD14365      M  California             8163.890428
# 7068  UP19263      M  California             7524.442436
# 7069  Y167826      M  California             2611.836866
#
#      number of open complaints     policy type  vehicle class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# ...

# %%
data.drop(['education', 'number of open complaints'],axis=1,inplace=True)

# %%
data
# Out:
#      customer gender          st customer lifetime value   income  \
# 0     RB50392    NaN  Washington                     NaN      0.0
# 1     QZ44356      F     Arizona              697953.59%      0.0
# 2     AI49188      F      Nevada             1288743.17%  48767.0
# 3     WW63253      M  California              764586.18%      0.0
# 4     GA49547      M  Washington              536307.65%  36357.0
# ...       ...    ...         ...                     ...      ...
# 7065  LA72316      M  California             23405.98798  71941.0
# 7066  PK87824      F  California             3096.511217  21604.0
# 7067  TD14365      M  California             8163.890428      0.0
# 7068  UP19263      M  California             7524.442436  21941.0
# 7069  Y167826      M  California             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data["customer lifetime value"] = pd.to_numeric(data["customer lifetime value"].str.replace('%', '')) * 100

# %%
data
# Out:
#      customer gender          st  customer lifetime value   income  \
# 0     RB50392    NaN  Washington                      NaN      0.0
# 1     QZ44356      F     Arizona               69795359.0      0.0
# 2     AI49188      F      Nevada              128874317.0  48767.0
# 3     WW63253      M  California               76458618.0      0.0
# 4     GA49547      M  Washington               53630765.0  36357.0
# ...       ...    ...         ...                      ...      ...
# 7065  LA72316      M  California                      NaN  71941.0
# 7066  PK87824      F  California                      NaN  21604.0
# 7067  TD14365      M  California                      NaN      0.0
# 7068  UP19263      M  California                      NaN  21941.0
# 7069  Y167826      M  California                      NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
duplicated_rows = data.duplicated()
num_duplicated_rows = sum(duplicated_rows)

# %%
num_duplicated_rows
# Out:
# 2943

# %%
data.drop_duplicates()
# Out:
#      customer gender          st  customer lifetime value   income  \
# 0     RB50392    NaN  Washington                      NaN      0.0
# 1     QZ44356      F     Arizona               69795359.0      0.0
# 2     AI49188      F      Nevada              128874317.0  48767.0
# 3     WW63253      M  California               76458618.0      0.0
# 4     GA49547      M  Washington               53630765.0  36357.0
# ...       ...    ...         ...                      ...      ...
# 7065  LA72316      M  California                      NaN  71941.0
# 7066  PK87824      F  California                      NaN  21604.0
# 7067  TD14365      M  California                      NaN      0.0
# 7068  UP19263      M  California                      NaN  21941.0
# 7069  Y167826      M  California                      NaN      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data[data['income']<=0]
# Out:
#      customer gender          st  customer lifetime value  income  \
# 0     RB50392    NaN  Washington                      NaN     0.0
# 1     QZ44356      F     Arizona               69795359.0     0.0
# 3     WW63253      M  California               76458618.0     0.0
# 7     CF85061      M     Arizona               72161003.0     0.0
# 10    SX51350      M  California               47389920.0     0.0
# ...       ...    ...         ...                      ...     ...
# 7059  WZ45103      F  California                      NaN     0.0
# 7061  RX91025      M  California                      NaN     0.0
# 7062  AC13887      M  California                      NaN     0.0
# 7067  TD14365      M  California                      NaN     0.0
# 7069  Y167826      M  California                      NaN     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
