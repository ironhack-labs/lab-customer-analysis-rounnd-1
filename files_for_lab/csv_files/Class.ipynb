# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
file2 = pd.read_csv('file2.txt',sep='\t')

# %%
data = pd.concat([file1,file2])

# %%
file1.head()
# Out:
#    CONTROLN STATE GENDER      HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
data.tail()
# Out:
#       CONTROLN STATE  GENDER   HV1  IC1    IC4  HVP1    IC5  POBC1  POBC2  \
# 1010    161838    CA       F  1953  304  380.0    47  13811     25     43
# 1011    161838    CA       F  1953  304  380.0    47  13811     25     43
# 1012    138311    AZ  Female  1708  437  684.0    36  29098      7     19
# 1013    123469    TX       M   561  493  540.0     1  16623      5     68
# 1014    135341    AZ  Female   700  205  295.0     0  12713      9     12
#
#         IC2  IC3    AVGGIFT  TCODE   DOB DOMAIN  TARGET_D
# 1010  353.0  337  13.500000      0  4212     C2      14.0
# 1011  353.0  337  13.500000      0  4212     C2      14.0
# 1012  586.0  551   9.769231      2  1403     S1      20.0
# 1013  529.0  506   5.200000      0     0     T2       5.0
# 1014  221.0  276  12.857143      0     0     C2      12.0

# %%
len(data)
# Out:
# 2022

# %%
len(file1) + len(file2) == len(data)
# Out:
# True

# %%
data.columns
# Out:
# Index(['CONTROLN', 'STATE', 'GENDER', 'HV1', 'IC1', 'IC4', 'HVP1', 'IC5',
#        'POBC1', 'POBC2', 'IC2', 'IC3', 'AVGGIFT', 'TCODE', 'DOB', 'DOMAIN',
#        'TARGET_D'],
#       dtype='object')

# %%
data.shape
# Out:
# (2022, 17)

# %%
data.dtypes
# Out:
# CONTROLN      int64
# STATE        object
# GENDER       object
# HV1          object
# IC1           int64
# IC4         float64
# HVP1          int64
# IC5          object
# POBC1         int64
# POBC2         int64
# IC2         float64
# IC3           int64
# AVGGIFT     float64
# TCODE         int64
# DOB           int64
# DOMAIN       object
# TARGET_D    float64
# dtype: object

# %%
name = 'LUKE'
name.lower()
# Out:
# 'luke'

# %%
cols = []
for column in range(len(data.columns)):
    cols.append(data.columns[column].lower())
data.columns = cols

# %%
data.head()
# Out:
#    controln state gender      hv1  ic1    ic4  hvp1    ic5  pobc1  pobc2  \
# 0     44060    FL      M   AAA896  392  520.0     7  21975      6     16
# 1     96093    IL      M   537.00  365  473.0     0  19387      1     89
# 2     43333    FL      F   725.00  301  436.0     3  18837     11     17
# 3     21885    NC      M  AAA1095  401  413.0     7  14014      1     74
# 4    190108    FL      F   995.00  252  348.0     0  17991      5      6
#
#      ic2  ic3    avggift  tcode   dob domain  target_d
# 0  430.0  466  28.000000      1  1901     C2     100.0
# 1  415.0  410   5.666667      0     0     T2       7.0
# 2  340.0  361   4.111111      0  2501     C2       5.0
# 3  407.0  399  27.277778      0  2208     T2      38.0
# 4  280.0  316   6.000000     28     0     C2       5.0

# %%
data = data.rename(columns={'controln':'id','hv1':'median_home_val', 'ic1':'median_household_income'})

# %%
data
# Out:
#           id state  gender median_home_val  median_household_income    ic4  \
# 0      44060    FL       M          AAA896                      392  520.0
# 1      96093    IL       M          537.00                      365  473.0
# 2      43333    FL       F          725.00                      301  436.0
# 3      21885    NC       M         AAA1095                      401  413.0
# 4     190108    FL       F          995.00                      252  348.0
# ...      ...   ...     ...             ...                      ...    ...
# 1010  161838    CA       F            1953                      304  380.0
# 1011  161838    CA       F            1953                      304  380.0
# 1012  138311    AZ  Female            1708                      437  684.0
# 1013  123469    TX       M             561                      493  540.0
# 1014  135341    AZ  Female             700                      205  295.0
#
# ...

# %%
data.drop(['tcode'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['id', 'state', 'gender', 'median_home_val', 'median_household_income',
#        'ic4', 'hvp1', 'ic5', 'pobc1', 'pobc2', 'ic2', 'ic3', 'avggift', 'dob',
#        'domain', 'target_d'],
#       dtype='object')

# %%
filtered = data[data['gender']== 'M']

# %%
filtered.reset_index()
# Out:
#      index      id state gender median_home_val  median_household_income  \
# 0        0   44060    FL      M          AAA896                      392
# 1        1   96093    IL      M          537.00                      365
# 2        3   21885    NC      M         AAA1095                      401
# 3        5  100640    IL      M          764.00                      457
# 4        7  119038    TX      M          890.00                      519
# ..     ...     ...   ...    ...             ...                      ...
# 756    999   15332    NC      M             723                      371
# 757   1000   74235    MI      M             473                      327
# 758   1002  165509    CA      M            2213                      447
# 759   1006  125986    TX      M             533                      246
# 760   1013  123469    TX      M             561                      493
#
#        ic4  hvp1    ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  \
# ...

# %%
filtered.set_index('id')
# Out:
#        state gender median_home_val  median_household_income    ic4  hvp1  \
# id
# 44060     FL      M          AAA896                      392  520.0     7
# 96093     IL      M          537.00                      365  473.0     0
# 21885     NC      M         AAA1095                      401  413.0     7
# 100640    IL      M          764.00                      457  501.0     1
# 119038    TX      M          890.00                      519  560.0     0
# ...      ...    ...             ...                      ...    ...   ...
# 15332     NC      M             723                      371  456.0     0
# 74235     MI      M             473                      327  363.0     1
# 165509    CA      M            2213                      447  491.0    77
# 125986    TX      M             533                      246  308.0     1
# 123469    TX      M             561                      493  540.0     1
#
#           ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  target_d
# ...

# %%
filtered[1:4]
# Out:
#        id state gender median_home_val  median_household_income    ic4  hvp1  \
# 1   96093    IL      M          537.00                      365  473.0     0
# 3   21885    NC      M         AAA1095                      401  413.0     7
# 5  100640    IL      M          764.00                      457  501.0     1
#
#      ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  target_d
# 1  19387      1     89  415.0  410   5.666667     0     T2       7.0
# 3  14014      1     74  407.0  399  27.277778  2208     T2      38.0
# 5  16022      2     75  477.0  480  25.571429  6104     S2      30.0

# %%
filtered.iloc[1:4]
# Out:
#        id state gender median_home_val  median_household_income    ic4  hvp1  \
# 1   96093    IL      M          537.00                      365  473.0     0
# 3   21885    NC      M         AAA1095                      401  413.0     7
# 5  100640    IL      M          764.00                      457  501.0     1
#
#      ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  target_d
# 1  19387      1     89  415.0  410   5.666667     0     T2       7.0
# 3  14014      1     74  407.0  399  27.277778  2208     T2      38.0
# 5  16022      2     75  477.0  480  25.571429  6104     S2      30.0

# %%
rows = [0,1]
cols = ['id','gender']
filtered.loc[rows,cols]
# Out:
#        id gender
# 0   44060      M
# 0  190579      M
# 1   96093      M

# %%
filtered.iloc[[0,1],[0]]
# Out:
#       id
# 0  44060
# 1  96093

# %%
data._get_numeric_data()
# Out:
#           id  median_household_income    ic4  hvp1  pobc1  pobc2    ic2  ic3  \
# 0      44060                      392  520.0     7      6     16  430.0  466
# 1      96093                      365  473.0     0      1     89  415.0  410
# 2      43333                      301  436.0     3     11     17  340.0  361
# 3      21885                      401  413.0     7      1     74  407.0  399
# 4     190108                      252  348.0     0      5      6  280.0  316
# ...      ...                      ...    ...   ...    ...    ...    ...  ...
# 1010  161838                      304  380.0    47     25     43  353.0  337
# 1011  161838                      304  380.0    47     25     43  353.0  337
# 1012  138311                      437  684.0    36      7     19  586.0  551
# 1013  123469                      493  540.0     1      5     68  529.0  506
# 1014  135341                      205  295.0     0      9     12  221.0  276
#
#         avggift   dob  target_d
# ...

# %%
data.select_dtypes('object')
# Out:
#      state  gender median_home_val    ic5 domain
# 0       FL       M          AAA896  21975     C2
# 1       IL       M          537.00  19387     T2
# 2       FL       F          725.00  18837     C2
# 3       NC       M         AAA1095  14014     T2
# 4       FL       F          995.00  17991     C2
# ...    ...     ...             ...    ...    ...
# 1010    CA       F            1953  13811     C2
# 1011    CA       F            1953  13811     C2
# 1012    AZ  Female            1708  29098     S1
# 1013    TX       M             561  16623     T2
# 1014    AZ  Female             700  12713     C2
#
# [2022 rows x 5 columns]

# %%
pd.to_numeric(data['median_home_val'], errors='coerce')
# Out:
# 0          NaN
# 1        537.0
# 2        725.0
# 3          NaN
# 4        995.0
#          ...
# 1010    1953.0
# 1011    1953.0
# 1012    1708.0
# 1013     561.0
# 1014     700.0
# Name: median_home_val, Length: 2022, dtype: float64

# %%
data.drop_duplicates(subset=['state','gender','ic2','ic3'])
# Out:
#          id state gender median_home_val  median_household_income    ic4  \
# 0     44060    FL      M          AAA896                      392  520.0
# 1     96093    IL      M          537.00                      365  473.0
# 2     43333    FL      F          725.00                      301  436.0
# 3     21885    NC      M         AAA1095                      401  413.0
# 4    190108    FL      F          995.00                      252  348.0
# ..      ...   ...    ...             ...                      ...    ...
# 995  156152    CA      F            1115                      313  391.0
# 996   67177    MI      F             709                      504  539.0
# 997   34475    FL      M             696                      277  355.0
# 998  114803    OK      F             911                      384  613.0
# 999   15332    NC      M             723                      371  456.0
#
#      hvp1    ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  target_d
# ...

# %%
data['id'].replace('_', ' ')
# Out:
# 0        44060
# 1        96093
# 2        43333
# 3        21885
# 4       190108
#          ...
# 1010    161838
# 1011    161838
# 1012    138311
# 1013    123469
# 1014    135341
# Name: id, Length: 2022, dtype: int64

# %%
data
# Out:
#           id state  gender median_home_val  median_household_income    ic4  \
# 0      44060    FL       M          AAA896                      392  520.0
# 1      96093    IL       M          537.00                      365  473.0
# 2      43333    FL       F          725.00                      301  436.0
# 3      21885    NC       M         AAA1095                      401  413.0
# 4     190108    FL       F          995.00                      252  348.0
# ...      ...   ...     ...             ...                      ...    ...
# 1010  161838    CA       F            1953                      304  380.0
# 1011  161838    CA       F            1953                      304  380.0
# 1012  138311    AZ  Female            1708                      437  684.0
# 1013  123469    TX       M             561                      493  540.0
# 1014  135341    AZ  Female             700                      205  295.0
#
# ...

# %%
data.isna()
# Out:
#          id  state  gender  median_home_val  median_household_income    ic4  \
# 0     False  False   False            False                    False  False
# 1     False  False   False            False                    False  False
# 2     False  False   False            False                    False  False
# 3     False  False   False            False                    False  False
# 4     False  False   False            False                    False  False
# ...     ...    ...     ...              ...                      ...    ...
# 1010  False  False   False            False                    False  False
# 1011  False  False   False            False                    False  False
# 1012  False  False   False            False                    False  False
# 1013  False  False   False            False                    False  False
# 1014  False  False   False            False                    False  False
#
# ...

# %%
data.isna().sum()
# Out:
# id                          0
# state                       0
# gender                     70
# median_home_val             2
# median_household_income     0
# ic4                         1
# hvp1                        0
# ic5                         0
# pobc1                       0
# pobc2                       0
# ic2                         1
# ic3                         0
# avggift                     0
# dob                         0
# domain                      0
# target_d                    0
# dtype: int64

# %%
data.isna().sum()/len(data)*100
# Out:
# id                         0.000000
# state                      0.000000
# gender                     3.461919
# median_home_val            0.098912
# median_household_income    0.000000
# ic4                        0.049456
# hvp1                       0.000000
# ic5                        0.000000
# pobc1                      0.000000
# pobc2                      0.000000
# ic2                        0.049456
# ic3                        0.000000
# avggift                    0.000000
# dob                        0.000000
# domain                     0.000000
# target_d                   0.000000
# dtype: float64

# %%
nulls_df = pd.DataFrame(data.isna().sum()/len(data)).reset_index()
nulls_df.columns = ['column_name','percent_nulls']

# %%
nulls_df
# Out:
#                 column_name  percent_nulls
# 0                        id       0.000000
# 1                     state       0.000000
# 2                    gender       0.034619
# 3           median_home_val       0.000989
# 4   median_household_income       0.000000
# 5                       ic4       0.000495
# 6                      hvp1       0.000000
# 7                       ic5       0.000000
# 8                     pobc1       0.000000
# 9                     pobc2       0.000000
# 10                      ic2       0.000495
# 11                      ic3       0.000000
# 12                  avggift       0.000000
# 13                      dob       0.000000
# 14                   domain       0.000000
# 15                 target_d       0.000000

# %%
nulls_df['percent_nulls'] >= 0.03
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# Name: percent_nulls, dtype: bool

# %%
nulls_df[nulls_df['percent_nulls']>=0.03]
# Out:
#   column_name  percent_nulls
# 2      gender       0.034619

# %%
nulls_df[nulls_df['percent_nulls']>=0.03]['column_name']
# Out:
# 2    gender
# Name: column_name, dtype: object

# %%
nulls_df[nulls_df['percent_nulls']>=0.03]['column_name'].values
# Out:
# array(['gender'], dtype=object)

# %%
columns_to_drop = nulls_df[nulls_df['percent_nulls']>=0.03]['column_name'].values

# %%
data.drop(columns_to_drop,axis=1)
# Out:
#           id state median_home_val  median_household_income    ic4  hvp1  \
# 0      44060    FL          AAA896                      392  520.0     7
# 1      96093    IL          537.00                      365  473.0     0
# 2      43333    FL          725.00                      301  436.0     3
# 3      21885    NC         AAA1095                      401  413.0     7
# 4     190108    FL          995.00                      252  348.0     0
# ...      ...   ...             ...                      ...    ...   ...
# 1010  161838    CA            1953                      304  380.0    47
# 1011  161838    CA            1953                      304  380.0    47
# 1012  138311    AZ            1708                      437  684.0    36
# 1013  123469    TX             561                      493  540.0     1
# 1014  135341    AZ             700                      205  295.0     0
#
#         ic5  pobc1  pobc2    ic2  ic3    avggift   dob domain  target_d
# ...

# %%
import numpy as np

# %%
data['median_home_val']
# Out:
# 0        AAA896
# 1        537.00
# 2        725.00
# 3       AAA1095
# 4        995.00
#          ...
# 1010       1953
# 1011       1953
# 1012       1708
# 1013        561
# 1014        700
# Name: median_home_val, Length: 2022, dtype: object

# %%
data['median_home_val'] = pd.to_numeric(data['median_home_val'], errors='coerce')

# %%
np.mean(data['median_home_val'])
# Out:
# 1160.3510163609321

# %%
mean_median_home_value = np.mean(data['median_home_val'])

# %%
data['median_home_val'] = data['median_home_val'].fillna(mean_median_home_value)

# %%
data
# Out:
#           id state  gender  median_home_val  median_household_income    ic4  \
# 0      44060    FL       M      1160.351016                      392  520.0
# 1      96093    IL       M       537.000000                      365  473.0
# 2      43333    FL       F       725.000000                      301  436.0
# 3      21885    NC       M      1160.351016                      401  413.0
# 4     190108    FL       F       995.000000                      252  348.0
# ...      ...   ...     ...              ...                      ...    ...
# 1010  161838    CA       F      1953.000000                      304  380.0
# 1011  161838    CA       F      1953.000000                      304  380.0
# 1012  138311    AZ  Female      1708.000000                      437  684.0
# 1013  123469    TX       M       561.000000                      493  540.0
# 1014  135341    AZ  Female       700.000000                      205  295.0
#
# ...

# %%
data['gender'].isna().value_counts()
# Out:
# False    1952
# True       70
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].fillna('F')

# %%
data.to_csv('merged_clean_ver1.csv')

# %%
#LAMBDA FUNCTIONS
def f():
    sfsdfes
    return

# %%
# lambda input(s) : function
addition = lambda x,y : x + y

# %%
addition
# Out:
# <function __main__.<lambda>(x, y)>

# %%
square = lambda x : x*x

# %%
lst = [1,2,3,4,5,6,7,8,9]
new_list = []
for item in lst:
    new_list.append(square(item))

# %%
new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
for item in lst:
    if item % 2 == 0:
        new_list.append(square(item))

# %%
new_list
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 4, 16, 36, 64]

# %%
lambda x: x.lower()
# Out:
# <function __main__.<lambda>(x)>

# %%
# map(function,iterable)

# %%
map(lambda x: x.upper(),data.columns)

# %%
list(map(lambda x: x.upper(),data.columns)) #makes everything upper case
# Out:
# ['ID',
#  'STATE',
#  'GENDER',
#  'MEDIAN_HOME_VAL',
#  'MEDIAN_HOUSEHOLD_INCOME',
#  'IC4',
#  'HVP1',
#  'IC5',
#  'POBC1',
#  'POBC2',
#  'IC2',
#  'IC3',
#  'AVGGIFT',
#  'DOB',
#  'DOMAIN',
#  'TARGET_D']

# %%
data['gender'] = list(map(lambda x: x.upper(),data['gender']))

# %%
data['gender'].value_counts()
# Out:
# F          1052
# M           761
# MALE         75
# FEMALE       70
# U            36
# FEAMALE      15
# J            13
# Name: gender, dtype: int64

# %%
def clean(x):
    if x in ['M', 'MALE']:
        return ('M')
    elif x.startswith('F'):
        return('F')
    else: 
        return('U')

# %%
data['gender'] = list(map(clean,data['gender']))

# %%
data['gender'].value_counts()
# Out:
# F    1137
# M     836
# U      49
# Name: gender, dtype: int64

# %%
file = pd.read_csv('df_final_web_data.csv')

# %%
file.dtypes
# Out:
# Unnamed: 0.1     int64
# Unnamed: 0       int64
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
pd.to_datetime(file['date_time'], errors='coerce')
# Out:
# 0   2017-04-17 15:27:00
# 1   2017-04-17 15:26:00
# 2   2017-04-17 15:19:00
# 3   2017-04-17 15:19:00
# 4   2017-04-17 15:18:00
# 5   2017-04-17 15:17:00
# 6   2017-04-17 15:17:00
# 7   2017-04-17 15:16:00
# 8   2017-04-05 13:10:00
# 9   2017-04-05 13:09:00
# Name: date_time, dtype: datetime64[ns]

# %%
file['data_time'] =pd.to_datetime(file['date_time'], errors='coerce')

# %%
file['data_time'][0].day
# Out:
# 17

# %%
file['data_time'][0].month
# Out:
# 4

# %%
file['data_time'][0].year
# Out:
# 2017

# %%
file['data_time'][0].isoweekday()
# Out:
# 1

# %%
file['data_time'][0].hour
# Out:
# 15

# %%
file['data_time'][0].isoformat()
# Out:
# '2017-04-17T15:27:00'

# %%
file['data_time'][0].strftime(format='%d-%m-%y')
# Out:
# '17-04-17'

# %%
file['data_time'][0].strftime(format='%A-%B-%Y')
# Out:
# 'Monday-April-2017'

# %%
import time
from datetime import date

# %%
date.today()
# Out:
# datetime.date(2023, 2, 18)

# %%
#stings
.lower
.upper
.replace

# %%
string = "   I love data analytics! "

# %%
string.lstrip()
# Out:
# 'I love data analytics! '

# %%
string.rstrip()
# Out:
# '   I love data analytics!'

# %%
string.split()
# Out:
# ['I', 'love', 'data', 'analytics!']

# %%
string.rstrip('!')
# Out:
# '   I love data analytics! '

# %%
string.split('!')
# Out:
# ['   I love data analytics', ' ']
