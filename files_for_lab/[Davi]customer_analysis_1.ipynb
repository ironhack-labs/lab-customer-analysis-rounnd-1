# %%
import pandas as pd
import numpy as np

# %%
# Read the three files into python as dataframes
df1 = pd.read_csv(r'files_for_lab\csv_files\file1.csv'), 
df2 = pd.read_csv(r'files_for_lab\csv_files\file2.csv'),
df3 = pd.read_csv(r'files_for_lab\csv_files\file2.csv')

# %%
# Show the DataFrames shape (df1)
df1 = pd.read_csv(r'files_for_lab\csv_files\file1.csv')
df1.shape
# Out:
# (4008, 11)

# %%
# Show the DataFrames shape (df2)
df2 = pd.read_csv(r'files_for_lab\csv_files\file2.csv')
df2.shape
# Out:
# (996, 11)

# %%
# Show the DataFrames shape (df3)
df3 = pd.read_csv(r'files_for_lab\csv_files\file3.csv')
df3.shape
# Out:
# (7070, 11)

# %%
# Standardize header names.
df1.columns = df1.columns.str.lower().str.replace(' ', '_')
df2.columns = df2.columns.str.lower().str.replace(' ', '_')
df3.columns = df2.columns.str.lower().str.replace(' ', '_')

df3 = df3.rename(columns = {'state' : 'st'})

# %%
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df1_new_order = ['customer', 'gender', 'education', 'vehicle_class', 'st', 'income', 'policy_type', 'number_of_open_complaints', 'customer_lifetime_value', 'monthly_premium_auto', 'monthly_premium_auto', 'total_claim_amount']
order_df1 = df1[df1_new_order]
order_df1

df2_new_order = ['customer', 'gender', 'education', 'vehicle_class', 'st', 'income', 'policy_type', 'number_of_open_complaints', 'customer_lifetime_value', 'monthly_premium_auto', 'monthly_premium_auto', 'total_claim_amount']
order_df2 = df2[df2_new_order]

df3_new_order = ['customer', 'gender', 'education', 'vehicle_class', 'st', 'income', 'policy_type', 'number_of_open_complaints', 'customer_lifetime_value', 'monthly_premium_auto', 'monthly_premium_auto', 'total_claim_amount']
order_df3 = df3[df3_new_order]

# %%
# Concatenate the three dataframes
customer_data = pd.concat([order_df1, order_df2, order_df3]).reset_index(drop=True)
customer_data
# Out:
#       customer       gender             education  vehicle_class          st  \
# 0      RB50392          NaN                Master  Four-Door Car  Washington
# 1      QZ44356            F              Bachelor  Four-Door Car     Arizona
# 2      AI49188            F              Bachelor   Two-Door Car      Nevada
# 3      WW63253            M              Bachelor            SUV  California
# 4      GA49547            M  High School or Below  Four-Door Car  Washington
# ...        ...          ...                   ...            ...         ...
# 12069  LA72316  23405.98798              Bachelor  Four-Door Car  California
# 12070  PK87824  3096.511217               College  Four-Door Car  California
# 12071  TD14365  8163.890428              Bachelor  Four-Door Car  California
# 12072  UP19263  7524.442436               College  Four-Door Car  California
# 12073  Y167826  2611.836866               College   Two-Door Car  California
#
# ...

# %%
# Which columns are numerical?
numerical_cols1 = df1.select_dtypes(include = 'number').columns

# Print the numerical column names
numerical_cols1
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
# Which columns are numerical?
numerical_cols2 = df2.select_dtypes(include = 'number').columns

# Print the numerical column names
numerical_cols2
# Out:
# Index(['income', 'monthly_premium_auto', 'total_claim_amount'], dtype='object')

# %%
# Which columns are numerical?
numerical_cols3 = df3.select_dtypes(include = 'number').columns

# Print the numerical column names
numerical_cols3
# Out:
# Index(['gender', 'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type'],
#       dtype='object')

# %%
# Which columns are categorical?
categorical_cols1 = df1.describe(include = ['object'])
categorical_cols1
# Out:
#        customer      st gender education customer_lifetime_value  \
# count      1071    1071    954      1071                    1068
# unique     1071       8      5         6                    1027
# top     RB50392  Oregon      F  Bachelor              445811.34%
# freq          1     320    457       324                       4
#
#        number_of_open_complaints    policy_type  vehicle_class
# count                       1071           1071           1071
# unique                         6              3              6
# top                       1/0/00  Personal Auto  Four-Door Car
# freq                         830            780            576

# %%
# Which columns are categorical?
categorical_cols2 = df2.describe(include = ['object'])
categorical_cols2
# Out:
#        customer      st gender education customer_lifetime_value  \
# count       996     996    991       996                     992
# unique      996       6      4         6                     950
# top     GS98873  Oregon      F   College              552821.28%
# freq          1     303    527       311                       4
#
#        number_of_open_complaints    policy_type  vehicle_class
# count                        996            996            996
# unique                         6              3              6
# top                       1/0/00  Personal Auto  Four-Door Car
# freq                         796            756            519

# %%
# Which columns are categorical?
categorical_cols3 = df3.describe(include = ['object'])
categorical_cols3
# Out:
#        customer          st education customer_lifetime_value  \
# count      7070        7070      7070                    7070
# unique     7070           5         5                       2
# top     SA25987  California  Bachelor                       F
# freq          1        2544      2152                    3576
#
#        total_claim_amount  vehicle_class
# count                7070           7070
# unique                  3              6
# top         Personal Auto  Four-Door Car
# freq                 5256           3546

# %%
#Delet the columns education and number of open complaints
customer_data = customer_data.drop('education', axis=1)
customer_data = customer_data.drop('number_of_open_complaints', axis=1)

# %%
customer_data
# Out:
#       customer       gender  vehicle_class          st   income  \
# 0      RB50392          NaN  Four-Door Car  Washington      0.0
# 1      QZ44356            F  Four-Door Car     Arizona      0.0
# 2      AI49188            F   Two-Door Car      Nevada  48767.0
# 3      WW63253            M            SUV  California      0.0
# 4      GA49547            M  Four-Door Car  Washington  36357.0
# ...        ...          ...            ...         ...      ...
# 12069  LA72316  23405.98798  Four-Door Car  California  71941.0
# 12070  PK87824  3096.511217  Four-Door Car  California  21604.0
# 12071  TD14365  8163.890428  Four-Door Car  California      0.0
# 12072  UP19263  7524.442436  Four-Door Car  California  21941.0
# 12073  Y167826  2611.836866   Two-Door Car  California      0.0
#
#           policy_type customer_lifetime_value  monthly_premium_auto  \
# 0       Personal Auto                     NaN                1000.0
# ...

# %%
# Correct the values of the column customer lifetime value

'''
customer_data['customer_lifetime_value'] = customer_data['customer_lifetime_value'].str.rstrip('%').astype(float) / 100
customer_data
'''

# %%
# Check for duplicate rows in the data and remove if any.
customer_data = customer_data.drop_duplicates()
customer_data
# Out:
#       customer       gender  vehicle_class          st   income  \
# 0      RB50392          NaN  Four-Door Car  Washington      0.0
# 1      QZ44356            F  Four-Door Car     Arizona      0.0
# 2      AI49188            F   Two-Door Car      Nevada  48767.0
# 3      WW63253            M            SUV  California      0.0
# 4      GA49547            M  Four-Door Car  Washington  36357.0
# ...        ...          ...            ...         ...      ...
# 12069  LA72316  23405.98798  Four-Door Car  California  71941.0
# 12070  PK87824  3096.511217  Four-Door Car  California  21604.0
# 12071  TD14365  8163.890428  Four-Door Car  California      0.0
# 12072  UP19263  7524.442436  Four-Door Car  California  21941.0
# 12073  Y167826  2611.836866   Two-Door Car  California      0.0
#
#           policy_type customer_lifetime_value  monthly_premium_auto  \
# 0       Personal Auto                     NaN                1000.0
# ...

# %%
# Filter out the data for customers who have an income of 0 or less.
filt_data = customer_data[customer_data['income']<=0]
filt_data
# Out:
#       customer       gender  vehicle_class          st  income  \
# 0      RB50392          NaN  Four-Door Car  Washington     0.0
# 1      QZ44356            F  Four-Door Car     Arizona     0.0
# 3      WW63253            M            SUV  California     0.0
# 7      CF85061            M  Four-Door Car     Arizona     0.0
# 10     SX51350            M  Four-Door Car  California     0.0
# ...        ...          ...            ...         ...     ...
# 12063  WZ45103  5678.050167  Four-Door Car  California     0.0
# 12065  RX91025    19872.262            SUV  California     0.0
# 12066  AC13887  4628.995325   Two-Door Car  California     0.0
# 12071  TD14365  8163.890428  Four-Door Car  California     0.0
# 12073  Y167826  2611.836866   Two-Door Car  California     0.0
#
#           policy_type customer_lifetime_value  monthly_premium_auto  \
# 0       Personal Auto                     NaN                1000.0
# 1       Personal Auto              697953.59%                  94.0
# ...
