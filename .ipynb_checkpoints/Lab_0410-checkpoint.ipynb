# %%
import pandas as pd

tit_data1 = pd.read_csv("/Users/giulianamiranda/Documents/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file1.csv")
tit_data1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
tit_data2 = pd.read_csv("/Users/giulianamiranda/Documents/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file2.csv")
tit_data2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
tit_data3 = pd.read_csv("/Users/giulianamiranda/Documents/Labs/lab-customer-analysis-round-1/files_for_lab/csv_files/file3.csv")
tit_data3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
print(tit_data1.shape)
print(tit_data2.shape)
print(tit_data3.shape)
# Out:
# (4008, 11)
# (996, 11)
# (7070, 11)

# %%
cols = []

for i in range(len(tit_data1.columns)):
    cols.append(tit_data1.columns[i].lower().replace(' ', '_'))
    
tit_data1.columns = cols 
tit_data1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols2 = []

for x in range(len(tit_data2.columns)):
    cols2.append(tit_data2.columns[x].lower().replace(' ', '_'))
    
tit_data2.columns = cols2 
tit_data2

tit_data2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
cols3 = []

for w in range(len(tit_data3.columns)):
    cols3.append(tit_data3.columns[w].lower().replace(' ', '_'))
    
tit_data3.columns = cols3 
tit_data3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
tit_data1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
tit_data2 = tit_data2[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]
tit_data2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
tit_data3.columns

tit_data3 = tit_data3.rename(columns={'state' : 'st'})

tit_data3

tit_data3 = tit_data3[['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
df1 = tit_data1
df2 = tit_data2
df3 = tit_data2

tit_data = pd.concat([df1,df2,df3], axis = 0)
tit_data
# Out:
#     customer          st gender             education customer_lifetime_value  \
# 0    RB50392  Washington    NaN                Master                     NaN
# 1    QZ44356     Arizona      F              Bachelor              697953.59%
# 2    AI49188      Nevada      F              Bachelor             1288743.17%
# 3    WW63253  California      M              Bachelor              764586.18%
# 4    GA49547  Washington      M  High School or Below              536307.65%
# ..       ...         ...    ...                   ...                     ...
# 991  HV85198     Arizona      M                Master              847141.75%
# 992  BS91566     Arizona      F               College              543121.91%
# 993  IL40123      Nevada      F               College              568964.41%
# 994  MY32149  California      F                Master              368672.38%
# 995  SA91515  California      M              Bachelor              399258.39%
#
# ...

# %%
tit_data.dtypes

# Income, monthly_premium_auto, total_claim_amount
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
# Which columns are numerical?

# income, monthly_premium_auto, total_claim_amount 

# Which columns are categorical?
# customer , st, gender, education, customer_lifetime_value  , policy_type, vehicle_class

# %%
tit_data["customer_lifetime_value"]
# Out:
# 0              NaN
# 1       697953.59%
# 2      1288743.17%
# 3       764586.18%
# 4       536307.65%
#           ...
# 991     847141.75%
# 992     543121.91%
# 993     568964.41%
# 994     368672.38%
# 995     399258.39%
# Name: customer_lifetime_value, Length: 6000, dtype: object

# %%
# Delete the column education and the number of open complaints from the dataframe.
tit_data = tit_data.drop(['education', 'number_of_open_complaints'], axis = 1)
tit_data.columns
# Out:
# Index(['customer', 'st', 'gender', 'customer_lifetime_value', 'income',
#        'monthly_premium_auto', 'policy_type', 'vehicle_class',
#        'total_claim_amount'],
#       dtype='object')

# %%
def remove_percent(x: str):
    return x.replace('%', '')
# Out:
# '1'

# %%
tit_data['customer_lifetime_value'] = tit_data['customer_lifetime_value'].astype(str).apply(remove_percent).astype(float)
tit_data['customer_lifetime_value']
# Out:
# 0             NaN
# 1       697953.59
# 2      1288743.17
# 3       764586.18
# 4       536307.65
#           ...
# 991     847141.75
# 992     543121.91
# 993     568964.41
# 994     368672.38
# 995     399258.39
# Name: customer_lifetime_value, Length: 6000, dtype: float64

# %%
tit_data.dtypes

# %%
tit_data.shape
# Out:
# (6000, 9)

# %%
def multiply_100(x: float):
    return x*100

multiply_100(1.20)
# Out:
# 120.0

# %%
tit_data['customer_lifetime_value'] = tit_data['customer_lifetime_value'].apply(multiply_100)
tit_data['customer_lifetime_value']
# Out:
# 0              NaN
# 1       69795359.0
# 2      128874317.0
# 3       76458618.0
# 4       53630765.0
#           ...
# 991     84714175.0
# 992     54312191.0
# 993     56896441.0
# 994     36867238.0
# 995     39925839.0
# Name: customer_lifetime_value, Length: 6000, dtype: float64

# %%
tit_data[tit_data.duplicated()]
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 1072      NaN         NaN    NaN                      NaN      NaN
# 1073      NaN         NaN    NaN                      NaN      NaN
# 1074      NaN         NaN    NaN                      NaN      NaN
# 1075      NaN         NaN    NaN                      NaN      NaN
# 1076      NaN         NaN    NaN                      NaN      NaN
# ...       ...         ...    ...                      ...      ...
# 991   HV85198     Arizona      M               84714175.0  63513.0
# 992   BS91566     Arizona      F               54312191.0  58161.0
# 993   IL40123      Nevada      F               56896441.0  83640.0
# 994   MY32149  California      F               36867238.0      0.0
# 995   SA91515  California      M               39925839.0      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 1072                   NaN             NaN            NaN                 NaN
# ...

# %%
tit_data_droped = tit_data.drop_duplicates()
tit_data_droped
# Out:
#     customer          st gender  customer_lifetime_value   income  \
# 0    RB50392  Washington    NaN                      NaN      0.0
# 1    QZ44356     Arizona      F               69795359.0      0.0
# 2    AI49188      Nevada      F              128874317.0  48767.0
# 3    WW63253  California      M               76458618.0      0.0
# 4    GA49547  Washington      M               53630765.0  36357.0
# ..       ...         ...    ...                      ...      ...
# 991  HV85198     Arizona      M               84714175.0  63513.0
# 992  BS91566     Arizona      F               54312191.0  58161.0
# 993  IL40123      Nevada      F               56896441.0  83640.0
# 994  MY32149  California      F               36867238.0      0.0
# 995  SA91515  California      M               39925839.0      0.0
#
#      monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                  1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
condition = (tit_data_droped['income'] == 0) | (tit_data_droped['income'] < 0)
tit_data_droped[condition]
# Out:
#     customer          st gender  customer_lifetime_value  income  \
# 0    RB50392  Washington    NaN                      NaN     0.0
# 1    QZ44356     Arizona      F               69795359.0     0.0
# 3    WW63253  California      M               76458618.0     0.0
# 7    CF85061     Arizona      M               72161003.0     0.0
# 10   SX51350  California      M               47389920.0     0.0
# ..       ...         ...    ...                      ...     ...
# 981  HR64684      Oregon      M               86898225.0     0.0
# 986  KB99097  California      F               44629970.0     0.0
# 990  RT69513  California      F               47747517.0     0.0
# 994  MY32149  California      F               36867238.0     0.0
# 995  SA91515  California      M               39925839.0     0.0
#
#      monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                  1000.0   Personal Auto  Four-Door Car            2.704934
# ...
