# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\aidag\OneDrive\Escritorio\ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv', sep=',')
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2 = pd.read_csv(r'C:\Users\aidag\OneDrive\Escritorio\ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv', sep=',')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3 = pd.read_csv(r'C:\Users\aidag\OneDrive\Escritorio\ironhack\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv', sep=',')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df_shape = df.shape
df_shape
# Out:
# (4008, 11)

# %%
df2_shape = df2.shape
df2_shape
# Out:
# (996, 11)

# %%
df3_shape = df3.shape
df3_shape
# Out:
# (7070, 11)

# %%
df.columns = df.columns.str.upper()
df.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
df2.columns = df2.columns.str.upper()
df2.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'TOTAL CLAIM AMOUNT', 'POLICY TYPE', 'VEHICLE CLASS'],
#       dtype='object')

# %%
df3.columns = df3.columns.str.upper()
df3.columns
# Out:
# Index(['CUSTOMER', 'STATE', 'CUSTOMER LIFETIME VALUE', 'EDUCATION', 'GENDER',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS'],
#       dtype='object')

# %%
df_reordered = df[['GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE','CUSTOMER', 'ST',
       'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
       'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT']]
df_reordered
# Out:
#      GENDER             EDUCATION CUSTOMER LIFETIME VALUE CUSTOMER  \
# 0       NaN                Master                     NaN  RB50392
# 1         F              Bachelor              697953.59%  QZ44356
# 2         F              Bachelor             1288743.17%  AI49188
# 3         M              Bachelor              764586.18%  WW63253
# 4         M  High School or Below              536307.65%  GA49547
# ...     ...                   ...                     ...      ...
# 4003    NaN                   NaN                     NaN      NaN
# 4004    NaN                   NaN                     NaN      NaN
# 4005    NaN                   NaN                     NaN      NaN
# 4006    NaN                   NaN                     NaN      NaN
# 4007    NaN                   NaN                     NaN      NaN
#
#               ST   INCOME  MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  \
# 0     Washington      0.0                1000.0                    1/0/00
# ...

# %%
df2_reordered = df2[['GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE','CUSTOMER', 'ST',
       'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
       'TOTAL CLAIM AMOUNT', 'POLICY TYPE', 'VEHICLE CLASS']]
df2_reordered
# Out:
#     GENDER EDUCATION CUSTOMER LIFETIME VALUE CUSTOMER          ST  INCOME  \
# 0        F  Bachelor              323912.47%  GS98873     Arizona   16061
# 1        F    Master              462680.11%  CW49887  California   79487
# 2        F   College              899704.02%  MY31220  California   54230
# 3        F   College             2580706.30%  UH35128      Oregon   71210
# 4        F   College              380812.21%  WH52799     Arizona   94903
# ..     ...       ...                     ...      ...         ...     ...
# 991      M    Master              847141.75%  HV85198     Arizona   63513
# 992      F   College              543121.91%  BS91566     Arizona   58161
# 993      F   College              568964.41%  IL40123      Nevada   83640
# 994      F    Master              368672.38%  MY32149  California       0
# 995      M  Bachelor              399258.39%  SA91515  California       0
#
#      MONTHLY PREMIUM AUTO NUMBER OF OPEN COMPLAINTS  TOTAL CLAIM AMOUNT  \
# ...

# %%
df3_reordered = df3[['GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE', 'CUSTOMER', 'STATE',
       'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
       'POLICY TYPE', 'TOTAL CLAIM AMOUNT', 'VEHICLE CLASS']]
df3_reordered
# Out:
#      GENDER             EDUCATION  CUSTOMER LIFETIME VALUE CUSTOMER  \
# 0         M  High School or Below              3479.137523  SA25987
# 1         M                Master              2502.637401  TB86706
# 2         F              Bachelor              3265.156348  ZL73902
# 3         F  High School or Below              4455.843406  KX23516
# 4         M  High School or Below              7704.958480  FN77294
# ...     ...                   ...                      ...      ...
# 7065      M              Bachelor             23405.987980  LA72316
# 7066      F               College              3096.511217  PK87824
# 7067      M              Bachelor              8163.890428  TD14365
# 7068      M               College              7524.442436  UP19263
# 7069      M               College              2611.836866  Y167826
#
#            STATE  INCOME  MONTHLY PREMIUM AUTO  NUMBER OF OPEN COMPLAINTS  \
# 0     Washington       0                   104                          0
# ...

# %%
data = pd.concat([df, df2, df3], axis=1)
data
# Out:
#      CUSTOMER          ST GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      CUSTOMER LIFETIME VALUE   INCOME MONTHLY PREMIUM AUTO  \
# 0                        NaN      0.0               1000.0
# 1                 697953.59%      0.0                 94.0
# 2                1288743.17%  48767.0                108.0
# 3                 764586.18%      0.0                106.0
# ...

# %%
#the numerical columns are income, monthly ptrmium auto, number of complaints and total claim amount
#the rest of the columns are categorical, like gender etc

# %%
df_copy = data.copy()

# %%
columns_to_delete = ['EDUCATION', 'NUMBER OF OPEN COMPLAINTS']
df_copy = data.drop(columns_to_delete, axis=1)
df_copy
# Out:
#      CUSTOMER          ST  GENDER  CUSTOMER LIFETIME VALUE   INCOME  \
# 0     RB50392  Washington     NaN                      NaN      0.0
# 1     QZ44356     Arizona       F               697953.59%      0.0
# 2     AI49188      Nevada       F              1288743.17%  48767.0
# 3     WW63253  California       M               764586.18%      0.0
# 4     GA49547  Washington       M               536307.65%  36357.0
# ...       ...         ...     ...                      ...      ...
# 7065      NaN         NaN     NaN                      NaN      NaN
# 7066      NaN         NaN     NaN                      NaN      NaN
# 7067      NaN         NaN     NaN                      NaN      NaN
# 7068      NaN         NaN     NaN                      NaN      NaN
# 7069      NaN         NaN     NaN                      NaN      NaN
#
#      MONTHLY PREMIUM AUTO     POLICY TYPE  VEHICLE CLASS TOTAL CLAIM AMOUNT  \
# ...
