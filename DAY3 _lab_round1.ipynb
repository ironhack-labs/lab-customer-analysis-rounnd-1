# %%
# Instructions: 
#1 Read the three files into python as dataframes
#2 Show the DataFrame's shape.
#3 Standardize header names.
#4 Rearrange the columns in the dataframe as needed
#5 Concatenate the three dataframes
#6 Which columns are numerical?
#7 Which columns are categorical?
#8 Understand the meaning of all columns
#9 Perform the data cleaning operations mentioned so far in class
#10 Delete the column education and the number of open complaints from the dataframe.
#11 Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
#12 Check for duplicate rows in the data and remove if any.
#13 Filter out the data for customers who have an income of 0 or less.

# %%
#1. Read 3 files

# %%
import pandas as pd

# %%
df1 = pd.read_csv("file1.csv")
df2 = pd.read_csv("file2.csv")
df3 = pd.read_csv("file3.csv")

# %%
#2. shape

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %%
#3 Standardize header names.

# %%
df1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
cols1 = [col_name.lower().replace(" ","_") for col_name in df1.columns]
df1.columns = cols1
cols1
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1['customer_lifetime_value'] = df1['customer_lifetime_value'].str.rstrip("%").astype(float)*100
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                  69795359.0      0.0                  94.0
# 2                 128874317.0  48767.0                 108.0
# ...

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
cols2 = [col_name.lower().replace(" ", "_") for col_name in df2.columns]
df2.columns = cols2
cols2
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
df2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df2.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints     object
# total_claim_amount           float64
# policy_type                   object
# vehicle_class                 object
# dtype: object

# %%
df2['customer_lifetime_value'] = df2['customer_lifetime_value'].str.rstrip("%").astype(float)*100
df2
# Out:
#     customer          st gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor               32391247.0   16061
# 1    CW49887  California      F    Master               46268011.0   79487
# 2    MY31220  California      F   College               89970402.0   54230
# 3    UH35128      Oregon      F   College              258070630.0   71210
# 4    WH52799     Arizona      F   College               38081221.0   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master               84714175.0   63513
# 992  BS91566     Arizona      F   College               54312191.0   58161
# 993  IL40123      Nevada      F   College               56896441.0   83640
# 994  MY32149  California      F    Master               36867238.0       0
# 995  SA91515  California      M  Bachelor               39925839.0       0
#
# ...

# %%
df3.columns
# Out:
# Index(['Customer', 'State', 'Customer Lifetime Value', 'Education', 'Gender',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Total Claim Amount', 'Vehicle Class'],
#       dtype='object')

# %%
cols3 = [col_name.lower().replace(" ", "_") for col_name in df3.columns]
df3.columns = cols3
cols3
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#4 Rearrange the columns in the dataframe as needed

# %%
df1 = df1[['customer',
 'st',
 'customer_lifetime_value',
 'education',
 'gender',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'total_claim_amount',
 'vehicle_class']]

# %%
df2 = df2[['customer',
 'st',
 'customer_lifetime_value',
 'education',
 'gender',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'total_claim_amount',
 'vehicle_class']]

# %%
df3 = df3.rename(columns={'state':'st'})

# %%
df3 = df3[['customer',
 'st',
 'customer_lifetime_value',
 'education',
 'gender',
 'income',
 'monthly_premium_auto',
 'number_of_open_complaints',
 'policy_type',
 'total_claim_amount',
 'vehicle_class']]

# %%
#5 Concatenate the three dataframes

# %%
data = pd.concat([df1,df2,df3])
data
# Out:
#      customer          st  customer_lifetime_value             education  \
# 0     RB50392  Washington                      NaN                Master
# 1     QZ44356     Arizona             6.979536e+07              Bachelor
# 2     AI49188      Nevada             1.288743e+08              Bachelor
# 3     WW63253  California             7.645862e+07              Bachelor
# 4     GA49547  Washington             5.363076e+07  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             2.340599e+04              Bachelor
# 7066  PK87824  California             3.096511e+03               College
# 7067  TD14365  California             8.163890e+03              Bachelor
# 7068  UP19263  California             7.524442e+03               College
# 7069  Y167826  California             2.611837e+03               College
#
#      gender   income  monthly_premium_auto number_of_open_complaints  \
# ...

# %%
#6 Which columns are numerical?

# %%
data.dtypes
# Out:
# customer                      object
# st                            object
# customer_lifetime_value      float64
# education                     object
# gender                        object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# total_claim_amount           float64
# vehicle_class                 object
# dtype: object

# %%
data.select_dtypes(include=["float64"]).columns
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'total_claim_amount'],
#       dtype='object')

# %%
#7 Which columns are categorical?

# %%
data.select_dtypes(include=["object"]).columns
# Out:
# Index(['customer', 'st', 'education', 'gender', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
#8 Understand the meaning of all columns

# %%
#9 Perform the data cleaning operations mentioned so far in class

# %%
data.isna().sum()
# Out:
# customer                     2937
# st                           2937
# customer_lifetime_value      2944
# education                    2937
# gender                       3059
# income                       2937
# monthly_premium_auto         2937
# number_of_open_complaints    2937
# policy_type                  2937
# total_claim_amount           2937
# vehicle_class                2937
# dtype: int64

# %%
# Customer(ID). Select the rows that the customer (ID) is not missing. Duplicates will be checked after

# %%
# selected the rows that the customer value(ID) is not missing 
data = data[data['customer'].isna()==False]
data
# Out:
#      customer          st  customer_lifetime_value             education  \
# 0     RB50392  Washington                      NaN                Master
# 1     QZ44356     Arizona             6.979536e+07              Bachelor
# 2     AI49188      Nevada             1.288743e+08              Bachelor
# 3     WW63253  California             7.645862e+07              Bachelor
# 4     GA49547  Washington             5.363076e+07  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             2.340599e+04              Bachelor
# 7066  PK87824  California             3.096511e+03               College
# 7067  TD14365  California             8.163890e+03              Bachelor
# 7068  UP19263  California             7.524442e+03               College
# 7069  Y167826  California             2.611837e+03               College
#
#      gender   income  monthly_premium_auto number_of_open_complaints  \
# ...

# %%
data.isna().sum()
# Out:
# customer                       0
# st                             0
# customer_lifetime_value        7
# education                      0
# gender                       122
# income                         0
# monthly_premium_auto           0
# number_of_open_complaints      0
# policy_type                    0
# total_claim_amount             0
# vehicle_class                  0
# dtype: int64

# %%
# State (st). check the elements and rename it accordingly

# %%
data["st"].value_counts() #rename CALI to California, AZ to Arizona , WA to Washington
# Out:
# California    3032
# Oregon        2601
# Arizona       1630
# Nevada         882
# Washington     768
# Cali           120
# AZ              74
# WA              30
# Name: st, dtype: int64

# %%
data['st'] = data['st'].replace(['Cali', 'AZ', "WA"], ['California', 'Arizona', "Washington"])
data["st"].value_counts()
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/2315752957.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['st'] = data['st'].replace(['Cali', 'AZ', "WA"], ['California', 'Arizona', "Washington"])
# California    3152
# Oregon        2601
# Arizona       1704
# Nevada         882
# Washington     798
# Name: st, dtype: int64

# %%
# Customer value will be cleaned in exercise 11

# %%
# Gender. check the elements, rename it if necessary, fill missing values with "Unknown"

# %%
data["gender"].isna().sum()
# Out:
# 122

# %%
data['gender'] = data['gender'].fillna('Unknown')
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/4077042890.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender'] = data['gender'].fillna('Unknown')

# %%
data["gender"].value_counts()
# Out:
# F          4560
# M          4368
# Unknown     122
# Male         40
# female       30
# Femal        17
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].replace(['Male', 'female'], ['M',"F"])
data["gender"].value_counts()
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/3099084822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender'] = data['gender'].replace(['Male', 'female'], ['M',"F"])
# F          4590
# M          4408
# Unknown     122
# Femal        17
# Name: gender, dtype: int64

# %%
data['gender'] = data['gender'].replace(["Femal"], ["F"])
data["gender"].value_counts()
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/1003886770.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['gender'] = data['gender'].replace(["Femal"], ["F"])
# F          4607
# M          4408
# Unknown     122
# Name: gender, dtype: int64

# %%
# Income. Is a numerical variable (float64), will put them as integers (0 decimal)

# %%
data["income"].value_counts()
# Out:
# 0.0        2294
# 95697.0      13
# 26876.0       8
# 61108.0       8
# 10621.0       8
#            ...
# 26599.0       1
# 75774.0       1
# 85412.0       1
# 42968.0       1
# 21941.0       1
# Name: income, Length: 5655, dtype: int64

# %%
data['income'] = data['income'].apply(lambda x: int(x))
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/1925967716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['income'] = data['income'].apply(lambda x: int(x))

# %%
data["income"].value_counts()
# Out:
# 0        2294
# 95697      13
# 26876       8
# 61108       8
# 10621       8
#          ...
# 26599       1
# 75774       1
# 85412       1
# 42968       1
# 21941       1
# Name: income, Length: 5655, dtype: int64

# %%
data["income"].isna().sum()
# Out:
# 0

# %%
# Monthly premium auto. check elements, put them as integers. no missing values, as it was seen above

# %%
data["monthly_premium_auto"].value_counts()
# Out:
# 65.0     351
# 66.0     312
# 71.0     304
# 73.0     303
# 63.0     290
#         ...
# 178.0      1
# 204.0      1
# 281.0      1
# 275.0      1
# 286.0      1
# Name: monthly_premium_auto, Length: 209, dtype: int64

# %%
data['monthly_premium_auto'] = data['monthly_premium_auto'].apply(lambda x: int(x))
# Out:
# /var/folders/tm/9j0yn48n2b3cwplptxzlt9y80000gn/T/ipykernel_28555/2996648043.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['monthly_premium_auto'] = data['monthly_premium_auto'].apply(lambda x: int(x))

# %%
data["monthly_premium_auto"].value_counts()
# Out:
# 65     351
# 66     312
# 71     304
# 73     303
# 63     290
#       ...
# 178      1
# 204      1
# 281      1
# 275      1
# 286      1
# Name: monthly_premium_auto, Length: 209, dtype: int64

# %%
# Policy type. check elements. no missing values as it was seen above

# %%
data["policy_type"].value_counts()
# Out:
# Personal Auto     6792
# Corporate Auto    1965
# Special Auto       380
# Name: policy_type, dtype: int64

# %%
# total claim amount

# %%
data["total_claim_amount"].value_counts()
# Out:
# 316.800000    119
# 292.800000    111
# 312.000000    108
# 350.400000    107
# 321.600000    104
#              ...
# 434.757900      1
# 389.636991      1
# 114.743547      1
# 733.737214      1
# 790.784983      1
# Name: total_claim_amount, Length: 5070, dtype: int64

# %%
# vehicle class. no missing values as seen above

# %%
data["vehicle_class"].value_counts()
# Out:
# Four-Door Car    4641
# Two-Door Car     1896
# SUV              1774
# Sports Car        483
# Luxury SUV        182
# Luxury Car        161
# Name: vehicle_class, dtype: int64

# %%
#10 Delete the column education and the number of open complaints from the dataframe.

# %%
data = data.drop(["education", "number_of_open_complaints"], axis = 1)

# %%
data
# Out:
#      customer          st  customer_lifetime_value   gender  income  \
# 0     RB50392  Washington                      NaN  Unknown       0
# 1     QZ44356     Arizona             6.979536e+07        F       0
# 2     AI49188      Nevada             1.288743e+08        F   48767
# 3     WW63253  California             7.645862e+07        M       0
# 4     GA49547  Washington             5.363076e+07        M   36357
# ...       ...         ...                      ...      ...     ...
# 7065  LA72316  California             2.340599e+04        M   71941
# 7066  PK87824  California             3.096511e+03        F   21604
# 7067  TD14365  California             8.163890e+03        M       0
# 7068  UP19263  California             7.524442e+03        M   21941
# 7069  Y167826  California             2.611837e+03        M       0
#
#       monthly_premium_auto     policy_type  total_claim_amount  vehicle_class
# ...

# %%
#11 Correct the values in the column customer lifetime value. They are given as a percent, 
# so multiply them by 100 and change dtype to numerical type

# In the beggining , i transformed the numbers in the various df's, and now i dont have to do nothing

# %%
data['customer_lifetime_value'].isna().sum()
# Out:
# 7

# %%
data = data[data['customer_lifetime_value'].isna()==False]
data
# Out:
#      customer          st  customer_lifetime_value gender  income  \
# 1     QZ44356     Arizona             6.979536e+07      F       0
# 2     AI49188      Nevada             1.288743e+08      F   48767
# 3     WW63253  California             7.645862e+07      M       0
# 4     GA49547  Washington             5.363076e+07      M   36357
# 5     OC83172      Oregon             8.256298e+07      F   62902
# ...       ...         ...                      ...    ...     ...
# 7065  LA72316  California             2.340599e+04      M   71941
# 7066  PK87824  California             3.096511e+03      F   21604
# 7067  TD14365  California             8.163890e+03      M       0
# 7068  UP19263  California             7.524442e+03      M   21941
# 7069  Y167826  California             2.611837e+03      M       0
#
#       monthly_premium_auto     policy_type  total_claim_amount  vehicle_class
# 1                       94   Personal Auto         1131.464935  Four-Door Car
# ...

# %%
data.dtypes
# Out:
# customer                    object
# st                          object
# customer_lifetime_value    float64
# gender                      object
# income                       int64
# monthly_premium_auto         int64
# policy_type                 object
# total_claim_amount         float64
# vehicle_class               object
# dtype: object

# %%
#12 Check for duplicate rows in the data and remove if any.

# %%
data[data.duplicated()== False] 
data
# Out:
#      customer          st  customer_lifetime_value gender  income  \
# 1     QZ44356     Arizona             6.979536e+07      F       0
# 2     AI49188      Nevada             1.288743e+08      F   48767
# 3     WW63253  California             7.645862e+07      M       0
# 4     GA49547  Washington             5.363076e+07      M   36357
# 5     OC83172      Oregon             8.256298e+07      F   62902
# ...       ...         ...                      ...    ...     ...
# 7065  LA72316  California             2.340599e+04      M   71941
# 7066  PK87824  California             3.096511e+03      F   21604
# 7067  TD14365  California             8.163890e+03      M       0
# 7068  UP19263  California             7.524442e+03      M   21941
# 7069  Y167826  California             2.611837e+03      M       0
#
#       monthly_premium_auto     policy_type  total_claim_amount  vehicle_class
# 1                       94   Personal Auto         1131.464935  Four-Door Car
# ...

# %%
#13 Filter out the data for customers who have an income of 0 or less.

# %%
data[data["income"] <= 0]
