# %%
# Import Pandas library

import pandas as pd

#1. Load data

df1 = pd.read_csv(r'C:\Users\ljant\Desktop\Ironhack\02_Intro_Pandas\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv')
df2 = pd.read_csv(r'C:\Users\ljant\Desktop\Ironhack\02_Intro_Pandas\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv')
df3 = pd.read_csv(r'C:\Users\ljant\Desktop\Ironhack\02_Intro_Pandas\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv')

df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#2. Standardise header names


'''
- lower cases
- spaces to _
'''
# df1

cols = []
for i in range (len(df1.columns)):
    cols.append(df1.columns[i].lower().replace(' ','_'))
    
df1.columns = cols    
df1  

# df2
cols = []
for i in range (len(df2.columns)):
    cols.append(df2.columns[i].lower().replace(' ','_'))
    
df2.columns = cols    
df2

# df3
cols = []
for i in range (len(df3.columns)):
    cols.append(df3.columns[i].lower().replace(' ','_'))
    
df3.columns = cols    
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
# Checking for same column names
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
#3.1 Rearranging the data (I only want to analyse 'state', 'gender', 'education', 'customer_lifetime_value')

# df1 --> First, I need to change 'st' to 'state' in df1 so it aligns with df3

df1 = df1.rename(columns = {'st': 'state'})
df1

# Now, make new df with only the columns I want

df1_adj = df1[['state','gender', 'education', 'customer_lifetime_value']]
df1_adj
# Out:
#            state gender             education customer_lifetime_value
# 0     Washington    NaN                Master                     NaN
# 1        Arizona      F              Bachelor              697953.59%
# 2         Nevada      F              Bachelor             1288743.17%
# 3     California      M              Bachelor              764586.18%
# 4     Washington      M  High School or Below              536307.65%
# ...          ...    ...                   ...                     ...
# 4003         NaN    NaN                   NaN                     NaN
# 4004         NaN    NaN                   NaN                     NaN
# 4005         NaN    NaN                   NaN                     NaN
# 4006         NaN    NaN                   NaN                     NaN
# 4007         NaN    NaN                   NaN                     NaN
#
# [4008 rows x 4 columns]

# %%
# Now for df2

# df2 --> First, I need to change 'st' to 'state'

df2 = df2.rename(columns = {'st': 'state'})
df1

# Now, make new df with only the columns I want

df2_adj = df2[['state','gender', 'education', 'customer_lifetime_value']]
df2_adj
# Out:
#           state gender education customer_lifetime_value
# 0       Arizona      F  Bachelor              323912.47%
# 1    California      F    Master              462680.11%
# 2    California      F   College              899704.02%
# 3        Oregon      F   College             2580706.30%
# 4       Arizona      F   College              380812.21%
# ..          ...    ...       ...                     ...
# 991     Arizona      M    Master              847141.75%
# 992     Arizona      F   College              543121.91%
# 993      Nevada      F   College              568964.41%
# 994  California      F    Master              368672.38%
# 995  California      M  Bachelor              399258.39%
#
# [996 rows x 4 columns]

# %%
# And now for df3

df3_adj = df2[['state','gender', 'education', 'customer_lifetime_value']]
df3_adj
# Out:
#           state gender education customer_lifetime_value
# 0       Arizona      F  Bachelor              323912.47%
# 1    California      F    Master              462680.11%
# 2    California      F   College              899704.02%
# 3        Oregon      F   College             2580706.30%
# 4       Arizona      F   College              380812.21%
# ..          ...    ...       ...                     ...
# 991     Arizona      M    Master              847141.75%
# 992     Arizona      F   College              543121.91%
# 993      Nevada      F   College              568964.41%
# 994  California      F    Master              368672.38%
# 995  California      M  Bachelor              399258.39%
#
# [996 rows x 4 columns]

# %%
#3.2 Concatenate the new adjusted columns

concate_data = pd.concat([df1_adj, df2_adj, df3_adj], axis = 0)
concate_data
# Out:
#           state gender             education customer_lifetime_value
# 0    Washington    NaN                Master                     NaN
# 1       Arizona      F              Bachelor              697953.59%
# 2        Nevada      F              Bachelor             1288743.17%
# 3    California      M              Bachelor              764586.18%
# 4    Washington      M  High School or Below              536307.65%
# ..          ...    ...                   ...                     ...
# 991     Arizona      M                Master              847141.75%
# 992     Arizona      F               College              543121.91%
# 993      Nevada      F               College              568964.41%
# 994  California      F                Master              368672.38%
# 995  California      M              Bachelor              399258.39%
#
# [6000 rows x 4 columns]

# %%
##4.1 And now the whole data ;-)
## Giving df2 and df3 the same order of columns as df1

df1.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2 = df2[['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]
df2
# Out:
#     customer       state gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
df3 = df3[['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]
df3
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value  income  monthly_premium_auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
# Before concating the dfs, I want to take out the '%' in df1 & 2 in customer_lifetime_value

df1.dtypes
df1['customer_lifetime_value'] = pd.to_numeric(df1['customer_lifetime_value'].str.strip('%'))
df1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                   697953.59      0.0                  94.0
# 2                  1288743.17  48767.0                 108.0
# ...

# %%
df1.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
df2['customer_lifetime_value'] = pd.to_numeric(df2['customer_lifetime_value'].str.strip('%'))
df2
# Out:
#     customer       state gender education  customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor                323912.47   16061
# 1    CW49887  California      F    Master                462680.11   79487
# 2    MY31220  California      F   College                899704.02   54230
# 3    UH35128      Oregon      F   College               2580706.30   71210
# 4    WH52799     Arizona      F   College                380812.21   94903
# ..       ...         ...    ...       ...                      ...     ...
# 991  HV85198     Arizona      M    Master                847141.75   63513
# 992  BS91566     Arizona      F   College                543121.91   58161
# 993  IL40123      Nevada      F   College                568964.41   83640
# 994  MY32149  California      F    Master                368672.38       0
# 995  SA91515  California      M  Bachelor                399258.39       0
#
# ...

# %%
df2.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value      float64
# income                         int64
# monthly_premium_auto           int64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
#4.2 Concatenate the whole data

concate_data = pd.concat([df1, df2, df3], axis = 0)
concate_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer_lifetime_value   income  monthly_premium_auto  \
# 0                         NaN      0.0                1000.0
# 1                6.979536e+05      0.0                  94.0
# 2                1.288743e+06  48767.0                 108.0
# ...

# %%
#5. Show only numerical columns of the new data frame

numeric_cols1 = concate_data.select_dtypes(include=['int', 'float'])
numeric_cols1

# If only the names of the columns need to be shown:
#add '.columns'

numeric_cols2 = concate_data.select_dtypes(include=['int', 'float']).columns
    
print(numeric_cols2)
# Out:
# Index(['customer_lifetime_value', 'income', 'monthly_premium_auto',
#        'total_claim_amount'],
#       dtype='object')

# %%
#6. Show only categorical columns of the new data frame

categorical_cols = concate_data.select_dtypes(include=['object']).columns
categorical_cols
# Out:
# Index(['customer', 'state', 'gender', 'education', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
#7. Data cleaning

#7.1 Drop the columns 'education' and 'number_of_open_complaints'

concate_data = concate_data.drop (['education', 'number_of_open_complaints'], axis = 1)
concate_data

# only 9 columns left and 12.074 rows
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#7.2 Adjust the 'customer_lifetime_value' (multiply and set as nummeric value)

# -> I've done that before concating the dfs

# %%
#7.3 Check for duplicated rows and drop the

# a) see duplicated rows

duplicate_rows = concate_data.duplicated()
print(duplicate_rows)

# b) sum them

duplicate_count = concate_data.duplicated().sum()
print(duplicate_count)

# c) drop them (but keeping original data)

clean_data = concate_data.drop_duplicates()
clean_data

## now only 9.135 rows left
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool
# 2939
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# ...

# %%
#7.4 Filter out the data for customers wo have an incme of 0 or less

adj_data = clean_data[clean_data['income'] > 0]
adj_data

#now only 6.840 rows left
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# 5     OC83172      Oregon      F             8.256298e+05  62902.0
# 6     XZ87318      Oregon      F             5.380899e+05  55350.0
# 8     DY87989      Oregon      M             2.412750e+06  14072.0
# ...       ...         ...    ...                      ...      ...
# 7063  TF56202  California      M             5.032165e+03  66367.0
# 7064  YM19146  California      F             4.100399e+03  47761.0
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...

# %%
# adjusting finally the index to the right numbers
adj_data = adj_data.reset_index(drop=True)
adj_data
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     AI49188      Nevada      F             1.288743e+06  48767.0
# 1     GA49547  Washington      M             5.363077e+05  36357.0
# 2     OC83172      Oregon      F             8.256298e+05  62902.0
# 3     XZ87318      Oregon      F             5.380899e+05  55350.0
# 4     DY87989      Oregon      M             2.412750e+06  14072.0
# ...       ...         ...    ...                      ...      ...
# 6835  TF56202  California      M             5.032165e+03  66367.0
# 6836  YM19146  California      F             4.100399e+03  47761.0
# 6837  LA72316  California      M             2.340599e+04  71941.0
# 6838  PK87824  California      F             3.096511e+03  21604.0
# 6839  UP19263  California      M             7.524442e+03  21941.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                    108.0   Personal Auto   Two-Door Car          566.472247
# ...
