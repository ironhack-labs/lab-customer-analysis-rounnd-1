# %%
import pandas as pd

# %%
df1 = pd.read_csv('files_for_lab/csv_files/file1.csv', sep=',')
df1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2 = pd.read_csv('files_for_lab/csv_files/file2.csv', sep=',')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3 = pd.read_csv('files_for_lab/csv_files/file3.csv', sep=',')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df1 = df1.rename(columns={'ST':'STATE'})
display(df1)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
df2 = df2.rename(columns={'ST':'STATE'})
display(df2)
# Out:
#     CUSTOMER       STATE GENDER EDUCATION CUSTOMER_LIFETIME_VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY_PREMIUM_AUTO NUMBER_OF_OPEN_COMPLAINTS  TOTAL_CLAIM_AMOUNT  \
# ...

# %%
df3 = df3.rename(columns={'Gender':'GENDER', 'State':'STATE'})

# %%
df1.columns = df1.columns.str.upper().str.replace(" ", "_")
display(df1)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns = df2.columns.str.upper().str.replace(" ", "_")
df2
# Out:
#     CUSTOMER          ST GENDER EDUCATION CUSTOMER_LIFETIME_VALUE  INCOME  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      MONTHLY_PREMIUM_AUTO NUMBER_OF_OPEN_COMPLAINTS  TOTAL_CLAIM_AMOUNT  \
# ...

# %%
df3.columns = df3.columns.str.upper().str.replace(" ", "_")
df3
# Out:
#      CUSTOMER       STATE  CUSTOMER_LIFETIME_VALUE             EDUCATION  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      GENDER  INCOME  MONTHLY_PREMIUM_AUTO  NUMBER_OF_OPEN_COMPLAINTS  \
# ...

# %%
data = pd.concat([df1,df2, df3], axis=0)
display(data)
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.shape
# Out:
# (12074, 11)

# %%
data.drop_duplicates()
# Out:
#      CUSTOMER       STATE GENDER             EDUCATION  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      CUSTOMER_LIFETIME_VALUE   INCOME  MONTHLY_PREMIUM_AUTO  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
print(len(data.columns))
# Out:
# 11

# %%
print(data.size)
# Out:
# 132814

# %%
data = data.drop(columns=["EDUCATION", "NUMBER_OF_OPEN_COMPLAINTS"])
display(data)
# Out:
#      CUSTOMER       STATE GENDER CUSTOMER_LIFETIME_VALUE   INCOME  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       MONTHLY_PREMIUM_AUTO     POLICY_TYPE  VEHICLE_CLASS  TOTAL_CLAIM_AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# Out:
# CUSTOMER                    object
# STATE                       object
# GENDER                      object
# CUSTOMER_LIFETIME_VALUE     object
# INCOME                     float64
# MONTHLY_PREMIUM_AUTO       float64
# POLICY_TYPE                 object
# VEHICLE_CLASS               object
# TOTAL_CLAIM_AMOUNT         float64
# dtype: object

# %%
column_name = 'CUSTOMER_LIFETIME_VALUE'
customer_lifetime_column = data[column_name]
index = 0
for number in data[column_name]:
    if isinstance(number,str) and '%' in number:
        number = number.replace('%','')
        number = float(number)*100
        data[column_name].update({index:number})
        
    index += 1  
    

data[column_name] = pd.to_numeric(data[column_name])
data.dtypes
# Out:
# CUSTOMER                    object
# STATE                       object
# GENDER                      object
# CUSTOMER_LIFETIME_VALUE    float64
# INCOME                     float64
# MONTHLY_PREMIUM_AUTO       float64
# POLICY_TYPE                 object
# VEHICLE_CLASS               object
# TOTAL_CLAIM_AMOUNT         float64
# dtype: object

# %%
data.drop_duplicates()
# Out:
#      CUSTOMER       STATE GENDER  CUSTOMER_LIFETIME_VALUE   INCOME  \
# 0     RB50392  Washington    NaN             3.239125e+07      0.0
# 1     QZ44356     Arizona      F             4.626801e+07      0.0
# 2     AI49188      Nevada      F             8.997040e+07  48767.0
# 3     WW63253  California      M             5.363076e+07      0.0
# 4     GA49547  Washington      M             8.256298e+07  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       MONTHLY_PREMIUM_AUTO     POLICY_TYPE  VEHICLE_CLASS  TOTAL_CLAIM_AMOUNT
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
positive_income=data['INCOME'] >0
data[positive_income]
# Out:
#      CUSTOMER       STATE GENDER  CUSTOMER_LIFETIME_VALUE   INCOME  \
# 2     AI49188      Nevada      F             8.997040e+07  48767.0
# 4     GA49547  Washington      M             8.256298e+07  36357.0
# 5     OC83172      Oregon      F             5.380899e+07  62902.0
# 6     XZ87318      Oregon      F             7.216100e+07  55350.0
# 8     DY87989      Oregon      M             7.388178e+07  14072.0
# ...       ...         ...    ...                      ...      ...
# 7063  TF56202  California      M             5.032165e+03  66367.0
# 7064  YM19146  California      F             4.100399e+03  47761.0
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
#
#       MONTHLY_PREMIUM_AUTO     POLICY_TYPE  VEHICLE_CLASS  TOTAL_CLAIM_AMOUNT
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...

# %%
data.dtypes
# Out:
# CUSTOMER                    object
# STATE                       object
# GENDER                      object
# CUSTOMER_LIFETIME_VALUE    float64
# INCOME                     float64
# MONTHLY_PREMIUM_AUTO       float64
# POLICY_TYPE                 object
# VEHICLE_CLASS               object
# TOTAL_CLAIM_AMOUNT         float64
# dtype: object

# %%
data_copy = data.copy()
data_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CUSTOMER                 9137 non-null   object
#  1   STATE                    9137 non-null   object
#  2   GENDER                   9015 non-null   object
#  3   CUSTOMER_LIFETIME_VALUE  9137 non-null   float64
#  4   INCOME                   9137 non-null   float64
#  5   MONTHLY_PREMIUM_AUTO     9137 non-null   float64
#  6   POLICY_TYPE              9137 non-null   object
#  7   VEHICLE_CLASS            9137 non-null   object
#  8   TOTAL_CLAIM_AMOUNT       9137 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 1.2+ MB
# 32391246.999999996
# 46268011.0
# 89970402.0
# 53630765.0
# 82562978.0
# 53808986.0
# 72161003.0
# 241275040.0
# 73881781.0
# 47389920.0
# 81971971.0
# 87987970.0
# 88190189.0
# 53844317.00000001
# 74631394.0
# 25668678.0
# ...

# %%
data1 = data_copy.dropna(axis=0,subset=["CUSTOMER", "STATE","CUSTOMER_LIFETIME_VALUE","INCOME","MONTHLY_PREMIUM_AUTO","POLICY_TYPE","VEHICLE_CLASS","TOTAL_CLAIM_AMOUNT"])
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9137 entries, 0 to 7069
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   CUSTOMER                 9137 non-null   object
#  1   STATE                    9137 non-null   object
#  2   GENDER                   9015 non-null   object
#  3   CUSTOMER_LIFETIME_VALUE  9137 non-null   float64
#  4   INCOME                   9137 non-null   float64
#  5   MONTHLY_PREMIUM_AUTO     9137 non-null   float64
#  6   POLICY_TYPE              9137 non-null   object
#  7   VEHICLE_CLASS            9137 non-null   object
#  8   TOTAL_CLAIM_AMOUNT       9137 non-null   float64
# dtypes: float64(4), object(5)
# memory usage: 713.8+ KB

# %%
data1['GENDER'] = data1['GENDER'].fillna('D')
data1.isna().sum()
# Out:
# /var/folders/55/gl9xjc597fg790y1ycvcbhp40000gn/T/ipykernel_1831/2665645256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['GENDER'] = data1['GENDER'].fillna('D')
# CUSTOMER                   0
# STATE                      0
# GENDER                     0
# CUSTOMER_LIFETIME_VALUE    0
# INCOME                     0
# MONTHLY_PREMIUM_AUTO       0
# POLICY_TYPE                0
# VEHICLE_CLASS              0
# TOTAL_CLAIM_AMOUNT         0
# dtype: int64

# %%
#No datetime related column in the data
