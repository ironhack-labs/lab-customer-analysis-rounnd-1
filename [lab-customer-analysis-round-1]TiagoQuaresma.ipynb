# %%
import pandas as pd

# %%
file1=pd.read_csv(r'C:\Users\Quaresma\Documents\IRONHACK\Lesson 3\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv')
file2=pd.read_csv(r'C:\Users\Quaresma\Documents\IRONHACK\Lesson 3\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv')
file3=pd.read_csv(r'C:\Users\Quaresma\Documents\IRONHACK\Lesson 3\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv')

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
file1.shape #(4008, 11)
file2.shape #(996, 11)
file3.shape  #(7070, 11)
# Out:
# (7070, 11)

# %%
cols1= []

for i in range(len(file1.columns)):
    cols1.append(file1.columns[i].lower().replace(" ", "_"))

    
file1.columns= cols1

# %%
cols2= []
for i in range(len(file2.columns)):
    cols2.append(file2.columns[i].lower().replace(" ", "_"))
    
file2.columns= cols2

file2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
cols3= []
for i in range(len(file3.columns)):
    cols3.append(file3.columns[i].lower().replace(" ", "_"))
    
file3.columns= cols3

file3= file3[['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
file1 = file1.rename(columns={'st': 'state'})
file1= file1[['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
file2 = file2.rename(columns={'st': 'state'})
file2= file2[['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']]

# %%
df_all= pd.concat([file1,file2,file3], axis=0)
df_all
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
categorical=df_all[['vehicle_class','policy_type','education','gender','state','customer']]
categorical
# Out:
#       vehicle_class     policy_type             education gender       state  \
# 0     Four-Door Car   Personal Auto                Master    NaN  Washington
# 1     Four-Door Car   Personal Auto              Bachelor      F     Arizona
# 2      Two-Door Car   Personal Auto              Bachelor      F      Nevada
# 3               SUV  Corporate Auto              Bachelor      M  California
# 4     Four-Door Car   Personal Auto  High School or Below      M  Washington
# ...             ...             ...                   ...    ...         ...
# 7065  Four-Door Car   Personal Auto              Bachelor      M  California
# 7066  Four-Door Car  Corporate Auto               College      F  California
# 7067  Four-Door Car  Corporate Auto              Bachelor      M  California
# 7068  Four-Door Car   Personal Auto               College      M  California
# 7069   Two-Door Car  Corporate Auto               College      M  California
#
#      customer
# 0     RB50392
# ...

# %%
numerical= df_all[['total_claim_amount','number_of_open_complaints','monthly_premium_auto','income','customer_lifetime_value']]
numerical
# Out:
#       total_claim_amount number_of_open_complaints  monthly_premium_auto  \
# 0               2.704934                    1/0/00                1000.0
# 1            1131.464935                    1/0/00                  94.0
# 2             566.472247                    1/0/00                 108.0
# 3             529.881344                    1/0/00                 106.0
# 4              17.269323                    1/0/00                  68.0
# ...                  ...                       ...                   ...
# 7065          198.234764                         0                  73.0
# 7066          379.200000                         0                  79.0
# 7067          790.784983                         3                  85.0
# 7068          691.200000                         0                  96.0
# 7069          369.600000                         0                  77.0
#
#        income customer_lifetime_value
# 0         0.0                     NaN
# ...

# %%
#customer
#state
#gender
#education
#customer_lifetime_value
#income
#monthly_premium_auto
#number_of_open_complaints
#policy_type
#vehicle_class
#total_claim_amount

# %%
df_all=df_all.drop(['education','number_of_open_complaints'],axis=1)

# %%
df_all
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df_all['customer_lifetime_value'] = df_all['customer_lifetime_value'].apply(lambda a: a if "%" not in str(a) else str(a).replace('%', ''))

df_all
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df_all.dtypes
# Out:
# customer                    object
# state                       object
# gender                      object
# customer_lifetime_value     object
# income                     float64
# monthly_premium_auto       float64
# policy_type                 object
# vehicle_class               object
# total_claim_amount         float64
# dtype: object

# %%
df_all['customer_lifetime_value'] = pd.to_numeric(df_all['customer_lifetime_value'], errors='coerce')
df_all
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+05      0.0
# 2     AI49188      Nevada      F             1.288743e+06  48767.0
# 3     WW63253  California      M             7.645862e+05      0.0
# 4     GA49547  Washington      M             5.363077e+05  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+04  71941.0
# 7066  PK87824  California      F             3.096511e+03  21604.0
# 7067  TD14365  California      M             8.163890e+03      0.0
# 7068  UP19263  California      M             7.524442e+03  21941.0
# 7069  Y167826  California      M             2.611837e+03      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
df_all['customer_lifetime_value'] = df_all['customer_lifetime_value']*100
df_all
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+07      0.0
# 2     AI49188      Nevada      F             1.288743e+08  48767.0
# 3     WW63253  California      M             7.645862e+07      0.0
# 4     GA49547  Washington      M             5.363076e+07  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+06  71941.0
# 7066  PK87824  California      F             3.096511e+05  21604.0
# 7067  TD14365  California      M             8.163890e+05      0.0
# 7068  UP19263  California      M             7.524442e+05  21941.0
# 7069  Y167826  California      M             2.611837e+05      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Check for duplicates
df_all[df_all.duplicated()]
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 1072      NaN         NaN    NaN                      NaN      NaN
# 1073      NaN         NaN    NaN                      NaN      NaN
# 1074      NaN         NaN    NaN                      NaN      NaN
# 1075      NaN         NaN    NaN                      NaN      NaN
# 1076      NaN         NaN    NaN                      NaN      NaN
# ...       ...         ...    ...                      ...      ...
# 4006      NaN         NaN    NaN                      NaN      NaN
# 4007      NaN         NaN    NaN                      NaN      NaN
# 0     GS98873     Arizona      F               32391247.0  16061.0
# 1     CW49887  California      F               46268011.0  79487.0
# 2     MY31220  California      F               89970402.0  54230.0
#
#       monthly_premium_auto    policy_type  vehicle_class  total_claim_amount
# 1072                   NaN            NaN            NaN                 NaN
# ...

# %%
## drop duplicates

df_all=df_all.drop_duplicates()

df_all
# Out:
#      customer       state gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F             6.979536e+07      0.0
# 2     AI49188      Nevada      F             1.288743e+08  48767.0
# 3     WW63253  California      M             7.645862e+07      0.0
# 4     GA49547  Washington      M             5.363076e+07  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M             2.340599e+06  71941.0
# 7066  PK87824  California      F             3.096511e+05  21604.0
# 7067  TD14365  California      M             8.163890e+05      0.0
# 7068  UP19263  California      M             7.524442e+05  21941.0
# 7069  Y167826  California      M             2.611837e+05      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Filter out the data for customers who have an income of 0 or less.
income= df_all.loc[(df_all.income <= 0)]
income
# Out:
#      customer       state gender  customer_lifetime_value  income  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F             6.979536e+07     0.0
# 3     WW63253  California      M             7.645862e+07     0.0
# 7     CF85061     Arizona      M             7.216100e+07     0.0
# 10    SX51350  California      M             4.738992e+07     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103  California      F             5.678050e+05     0.0
# 7061  RX91025  California      M             1.987226e+06     0.0
# 7062  AC13887  California      M             4.628995e+05     0.0
# 7067  TD14365  California      M             8.163890e+05     0.0
# 7069  Y167826  California      M             2.611837e+05     0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
