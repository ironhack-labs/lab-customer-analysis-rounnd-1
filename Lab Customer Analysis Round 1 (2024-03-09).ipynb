# %% [markdown]
# Abstract
# The objective of this data is to understand customer demographics and buying behavior. Later during the week, we will use predictive analytics to analyze the most profitable customers and how they interact. After that, we will take targeted actions to increase profitable customer response, retention, and growth.
#
# For this lab, we will gather the data from 3 csv files that are provided in the files_for_lab folder. Use that data and complete the data cleaning tasks as mentioned later in the instructions.
#
# Instructions
# Read the three files into python as dataframes
#
# Show the DataFrame's shape.
#
# Standardize header names.
#
# Rearrange the columns in the dataframe as needed
#
# Concatenate the three dataframes
#
# Which columns are numerical?
#
# Which columns are categorical?
#
# Understand the meaning of all columns
#
# Perform the data cleaning operations mentioned so far in class
#
# Delete the column education and the number of open complaints from the dataframe.
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
# Check for duplicate rows in the data and remove if any.
# Filter out the data for customers who have an income of 0 or less.

# %%
import pandas as pd

# %%
pd1=pd.read_csv(r"C:\Users\Usuari\Documents\IRONHACK\Work\Lehen astea\2024-03-09\Lab1\file1.csv")
pd2=pd.read_csv(r"C:\Users\Usuari\Documents\IRONHACK\Work\Lehen astea\2024-03-09\Lab1\file1.csv")
pd3=pd.read_csv(r"C:\Users\Usuari\Documents\IRONHACK\Work\Lehen astea\2024-03-09\Lab1\file1.csv")

# %%
pd1.shape
# Out:
# (4008, 11)

# %%
pd2.shape
# Out:
# (4008, 11)

# %%
pd3.shape
# Out:
# (4008, 11)

# %%
pd1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
pd2.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
pd3.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
pd3_1=pd3.rename(columns={"State":"ST"})

# %%
pd3_1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
columnas=list(pd1.columns)

# %%
columnas
# Out:
# ['Customer',
#  'ST',
#  'GENDER',
#  'Education',
#  'Customer Lifetime Value',
#  'Income',
#  'Monthly Premium Auto',
#  'Number of Open Complaints',
#  'Policy Type',
#  'Vehicle Class',
#  'Total Claim Amount']

# %%
titulos_nuevos={}
for columna in columnas:
    titulos_nuevos[columna]=columna.upper()

# %%
titulos_nuevos
# Out:
# {'Customer': 'CUSTOMER',
#  'ST': 'ST',
#  'GENDER': 'GENDER',
#  'Education': 'EDUCATION',
#  'Customer Lifetime Value': 'CUSTOMER LIFETIME VALUE',
#  'Income': 'INCOME',
#  'Monthly Premium Auto': 'MONTHLY PREMIUM AUTO',
#  'Number of Open Complaints': 'NUMBER OF OPEN COMPLAINTS',
#  'Policy Type': 'POLICY TYPE',
#  'Vehicle Class': 'VEHICLE CLASS',
#  'Total Claim Amount': 'TOTAL CLAIM AMOUNT'}

# %%
pd1=pd1.rename(columns=titulos_nuevos)

# %%
columnas=list(pd2.columns)
titulos_nuevos2={}
for columna in columnas:
    titulos_nuevos2[columna]=columna.upper()
pd2.rename(columns=titulos_nuevos2)   
pd2=pd2.rename(columns=titulos_nuevos2)

# %%
columnas=list(pd3_1.columns)
titulos_nuevos3_1={}
for columna in columnas:
    titulos_nuevos3_1[columna]=columna.upper()
pd3_1.rename(columns=titulos_nuevos3_1)  
pd3_1=pd3_1.rename(columns=titulos_nuevos3_1)

# %%
pd1=pd1[sorted(list(pd1.columns))] #para ordenarte alfabeticamente los titulos de las columnas

# %%
pd2=pd2[sorted(list(pd2.columns))]

# %%
pd3_1=pd3_1[sorted(list(pd3_1.columns))]

# %%
pd_concatenado = pd.concat([pd1, pd2, pd3_1], ignore_index=True)

# %%
pd_concatenado
# Out:
#       CUSTOMER CUSTOMER LIFETIME VALUE             EDUCATION GENDER   INCOME  \
# 0      RB50392                     NaN                Master    NaN      0.0
# 1      QZ44356              697953.59%              Bachelor      F      0.0
# 2      AI49188             1288743.17%              Bachelor      F  48767.0
# 3      WW63253              764586.18%              Bachelor      M      0.0
# 4      GA49547              536307.65%  High School or Below      M  36357.0
# ...        ...                     ...                   ...    ...      ...
# 12019      NaN                     NaN                   NaN    NaN      NaN
# 12020      NaN                     NaN                   NaN    NaN      NaN
# 12021      NaN                     NaN                   NaN    NaN      NaN
# 12022      NaN                     NaN                   NaN    NaN      NaN
# 12023      NaN                     NaN                   NaN    NaN      NaN
#
# ...

# %% [markdown]
# Variables numéricas: CUSTOMER LIFETIME VALUE, INCOME, MONTHLY PREMIUM AUTO, NUMBER OF OPEN COMPLAINTS, TOTAL CLAIM AMOUNT
# Variables categóricas: CUSTOMER, EDUCATION, GENDER, POLICY TYPE, ST, VEHICLE CLASS

# %%
pd_limpio = pd_concatenado.drop(['EDUCATION', 'NUMBER OF OPEN COMPLAINTS'], axis=1)

# %%
pd_limpio
# Out:
#       CUSTOMER CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0      RB50392                     NaN    NaN      0.0                1000.0
# 1      QZ44356              697953.59%      F      0.0                  94.0
# 2      AI49188             1288743.17%      F  48767.0                 108.0
# 3      WW63253              764586.18%      M      0.0                 106.0
# 4      GA49547              536307.65%      M  36357.0                  68.0
# ...        ...                     ...    ...      ...                   ...
# 12019      NaN                     NaN    NaN      NaN                   NaN
# 12020      NaN                     NaN    NaN      NaN                   NaN
# 12021      NaN                     NaN    NaN      NaN                   NaN
# 12022      NaN                     NaN    NaN      NaN                   NaN
# 12023      NaN                     NaN    NaN      NaN                   NaN
#
# ...

# %%
pd_limpio['CUSTOMER LIFETIME VALUE'] = pd_limpio['CUSTOMER LIFETIME VALUE'].str.rstrip('%').astype(float) * 100

# %%
pd_limpio
# Out:
#       CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0      RB50392                      NaN    NaN      0.0                1000.0
# 1      QZ44356               69795359.0      F      0.0                  94.0
# 2      AI49188              128874317.0      F  48767.0                 108.0
# 3      WW63253               76458618.0      M      0.0                 106.0
# 4      GA49547               53630765.0      M  36357.0                  68.0
# ...        ...                      ...    ...      ...                   ...
# 12019      NaN                      NaN    NaN      NaN                   NaN
# 12020      NaN                      NaN    NaN      NaN                   NaN
# 12021      NaN                      NaN    NaN      NaN                   NaN
# 12022      NaN                      NaN    NaN      NaN                   NaN
# 12023      NaN                      NaN    NaN      NaN                   NaN
#
# ...

# %%
# Paso 1: Identificar filas duplicadas (opcional)

duplicadas = pd_limpio.duplicated()
print("\nFilas duplicadas (True = duplicada):")
print(duplicadas)




# Paso 2: Eliminar filas duplicadas
# keep='first' indica que se mantiene la primera aparición y se eliminan las demás duplicaciones.
pd_relimpio = pd_limpio.drop_duplicates(keep='first')
# Out:
# Filas duplicadas (True = duplicada):
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 12019     True
# 12020     True
# 12021     True
# 12022     True
# 12023     True
# Length: 12024, dtype: bool

# %%
pd_relimpio
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 0     RB50392                      NaN    NaN      0.0                1000.0
# 1     QZ44356               69795359.0      F      0.0                  94.0
# 2     AI49188              128874317.0      F  48767.0                 108.0
# 3     WW63253               76458618.0      M      0.0                 106.0
# 4     GA49547               53630765.0      M  36357.0                  68.0
# ...       ...                      ...    ...      ...                   ...
# 1067  VJ51327              203149976.0      F  63209.0                 102.0
# 1068  GS98873               32391247.0      F  16061.0                  88.0
# 1069  CW49887               46268011.0      F  79487.0                 114.0
# 1070  MY31220               89970402.0      F  54230.0                 112.0
# 1071      NaN                      NaN    NaN      NaN                   NaN
#
# ...

# %%
pd_filtrado = pd_relimpio[pd_relimpio['INCOME'] > 0]

# %%
pd_filtrado
# Out:
#      CUSTOMER  CUSTOMER LIFETIME VALUE GENDER   INCOME  MONTHLY PREMIUM AUTO  \
# 2     AI49188              128874317.0      F  48767.0                 108.0
# 4     GA49547               53630765.0      M  36357.0                  68.0
# 5     OC83172               82562978.0      F  62902.0                  69.0
# 6     XZ87318               53808986.0      F  55350.0                  67.0
# 8     DY87989              241275040.0      M  14072.0                  71.0
# ...       ...                      ...    ...      ...                   ...
# 1066  TM65736               30595503.0      M  38644.0                  78.0
# 1067  VJ51327              203149976.0      F  63209.0                 102.0
# 1068  GS98873               32391247.0      F  16061.0                  88.0
# 1069  CW49887               46268011.0      F  79487.0                 114.0
# 1070  MY31220               89970402.0      F  54230.0                 112.0
#
# ...
