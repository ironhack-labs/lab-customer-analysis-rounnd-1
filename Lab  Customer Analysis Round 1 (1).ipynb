# %%
#Read the three files into python as dataframes
import pandas as pd

file1 = pd.read_csv(r'C:\Users\Anderson\Desktop\ironhack\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv')
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
import pandas as pd

file2 = pd.read_csv(r'C:\Users\Anderson\Desktop\ironhack\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv')
file2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
import pandas as pd

file3 = pd.read_csv(r'C:\Users\Anderson\Desktop\ironhack\day3\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv')
file3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
#Show the DataFrame's shape.
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
#Standardize header names.
cols = []
for i in range(len(file1.columns)): 
    cols.append(file1.columns[i].lower().replace(' ', '_'))
file1.columns = cols
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
cols = []
for i in range(len(file2.columns)): 
    cols.append(file2.columns[i].lower().replace(' ', '_'))
file2.columns = cols
file2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
cols = []
for i in range(len(file3.columns)): 
    cols.append(file3.columns[i].lower().replace(' ', '_'))
file3.columns = cols
file3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %%
#Rearrange the columns in the dataframe as needed

file1.columns.to_list()
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
file1 = file1[['customer', 'customer_lifetime_value','gender','education', 'income','st','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount']]

# %%
file1
# Out:
#      customer customer_lifetime_value gender             education   income  \
# 0     RB50392                     NaN    NaN                Master      0.0
# 1     QZ44356              697953.59%      F              Bachelor      0.0
# 2     AI49188             1288743.17%      F              Bachelor  48767.0
# 3     WW63253              764586.18%      M              Bachelor      0.0
# 4     GA49547              536307.65%      M  High School or Below  36357.0
# ...       ...                     ...    ...                   ...      ...
# 4003      NaN                     NaN    NaN                   NaN      NaN
# 4004      NaN                     NaN    NaN                   NaN      NaN
# 4005      NaN                     NaN    NaN                   NaN      NaN
# 4006      NaN                     NaN    NaN                   NaN      NaN
# 4007      NaN                     NaN    NaN                   NaN      NaN
#
# ...

# %%
file2.columns.to_list()
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'total_claim_amount',
#  'policy_type',
#  'vehicle_class']

# %%
file2 = file2[['customer', 'customer_lifetime_value','gender','education', 'income','st','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount']]

# %%
file2
# Out:
#     customer customer_lifetime_value gender education  income          st  \
# 0    GS98873              323912.47%      F  Bachelor   16061     Arizona
# 1    CW49887              462680.11%      F    Master   79487  California
# 2    MY31220              899704.02%      F   College   54230  California
# 3    UH35128             2580706.30%      F   College   71210      Oregon
# 4    WH52799              380812.21%      F   College   94903     Arizona
# ..       ...                     ...    ...       ...     ...         ...
# 991  HV85198              847141.75%      M    Master   63513     Arizona
# 992  BS91566              543121.91%      F   College   58161     Arizona
# 993  IL40123              568964.41%      F   College   83640      Nevada
# 994  MY32149              368672.38%      F    Master       0  California
# 995  SA91515              399258.39%      M  Bachelor       0  California
#
#      monthly_premium_auto number_of_open_complaints     policy_type  \
# ...

# %%
file3.columns.to_list()
# Out:
# ['customer',
#  'state',
#  'customer_lifetime_value',
#  'education',
#  'gender',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'total_claim_amount',
#  'vehicle_class']

# %%
file3 = file3[['customer', 'customer_lifetime_value','gender','education', 'income','state','monthly_premium_auto','number_of_open_complaints','policy_type','vehicle_class','total_claim_amount']]

# %%
file3
# Out:
#      customer  customer_lifetime_value gender             education  income  \
# 0     SA25987              3479.137523      M  High School or Below       0
# 1     TB86706              2502.637401      M                Master       0
# 2     ZL73902              3265.156348      F              Bachelor   25820
# 3     KX23516              4455.843406      F  High School or Below       0
# 4     FN77294              7704.958480      M  High School or Below   30366
# ...       ...                      ...    ...                   ...     ...
# 7065  LA72316             23405.987980      M              Bachelor   71941
# 7066  PK87824              3096.511217      F               College   21604
# 7067  TD14365              8163.890428      M              Bachelor       0
# 7068  UP19263              7524.442436      M               College   21941
# 7069  Y167826              2611.836866      M               College       0
#
# ...

# %%
file3
# Out:
#      customer  customer_lifetime_value gender             education  income  \
# 0     SA25987              3479.137523      M  High School or Below       0
# 1     TB86706              2502.637401      M                Master       0
# 2     ZL73902              3265.156348      F              Bachelor   25820
# 3     KX23516              4455.843406      F  High School or Below       0
# 4     FN77294              7704.958480      M  High School or Below   30366
# ...       ...                      ...    ...                   ...     ...
# 7065  LA72316             23405.987980      M              Bachelor   71941
# 7066  PK87824              3096.511217      F               College   21604
# 7067  TD14365              8163.890428      M              Bachelor       0
# 7068  UP19263              7524.442436      M               College   21941
# 7069  Y167826              2611.836866      M               College       0
#
# ...

# %%
file3 = file3.rename(columns={'state': 'st'})

# %%
file3
# Out:
#      customer  customer_lifetime_value gender             education  income  \
# 0     SA25987              3479.137523      M  High School or Below       0
# 1     TB86706              2502.637401      M                Master       0
# 2     ZL73902              3265.156348      F              Bachelor   25820
# 3     KX23516              4455.843406      F  High School or Below       0
# 4     FN77294              7704.958480      M  High School or Below   30366
# ...       ...                      ...    ...                   ...     ...
# 7065  LA72316             23405.987980      M              Bachelor   71941
# 7066  PK87824              3096.511217      F               College   21604
# 7067  TD14365              8163.890428      M              Bachelor       0
# 7068  UP19263              7524.442436      M               College   21941
# 7069  Y167826              2611.836866      M               College       0
#
# ...

# %%
#Concatenate the three dataframes

file4 = pd.concat([file1, file2, file3], axis=0)

# %%
file4
# Out:
#      customer customer_lifetime_value gender             education   income  \
# 0     RB50392                     NaN    NaN                Master      0.0
# 1     QZ44356              697953.59%      F              Bachelor      0.0
# 2     AI49188             1288743.17%      F              Bachelor  48767.0
# 3     WW63253              764586.18%      M              Bachelor      0.0
# 4     GA49547              536307.65%      M  High School or Below  36357.0
# ...       ...                     ...    ...                   ...      ...
# 7065  LA72316             23405.98798      M              Bachelor  71941.0
# 7066  PK87824             3096.511217      F               College  21604.0
# 7067  TD14365             8163.890428      M              Bachelor      0.0
# 7068  UP19263             7524.442436      M               College  21941.0
# 7069  Y167826             2611.836866      M               College      0.0
#
# ...

# %%
file4.shape
# Out:
# (12074, 11)

# %%
#Which columns are numerical?
#file4._get_numeric_data()
num_cols = file4.select_dtypes(include=['number']).columns.tolist()
num_cols
# Out:
# ['income', 'monthly_premium_auto', 'total_claim_amount']

# %%
#Which columns are categorical?
categ_cols = file4.select_dtypes(exclude=['number']).columns.tolist()
categ_cols
# Out:
# ['customer',
#  'customer_lifetime_value',
#  'gender',
#  'education',
#  'st',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class']

# %%
file4['customer_lifetime_value']
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
#Understand the meaning of all columns

file4.shape
# Out:
# (12074, 11)

# %%
file4.dtypes
# Out:
# customer                      object
# customer_lifetime_value       object
# gender                        object
# education                     object
# income                       float64
# st                            object
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
file4['customer'].unique()
# Out:
# array(['RB50392', 'QZ44356', 'AI49188', ..., 'TD14365', 'UP19263',
#        'Y167826'], dtype=object)

# %%
file4.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
condition = file4.duplicated()
file4[condition]
# Out:
#      customer customer_lifetime_value gender education   income          st  \
# 1072      NaN                     NaN    NaN       NaN      NaN         NaN
# 1073      NaN                     NaN    NaN       NaN      NaN         NaN
# 1074      NaN                     NaN    NaN       NaN      NaN         NaN
# 1075      NaN                     NaN    NaN       NaN      NaN         NaN
# 1076      NaN                     NaN    NaN       NaN      NaN         NaN
# ...       ...                     ...    ...       ...      ...         ...
# 4006      NaN                     NaN    NaN       NaN      NaN         NaN
# 4007      NaN                     NaN    NaN       NaN      NaN         NaN
# 0     GS98873              323912.47%      F  Bachelor  16061.0     Arizona
# 1     CW49887              462680.11%      F    Master  79487.0  California
# 2     MY31220              899704.02%      F   College  54230.0  California
#
# ...

# %%
#Perform the data cleaning operations mentioned so far in class

#Delete the column education and the number of open complaints from the dataframe.
file4 = file4.drop(['education'], axis = 1)
file4
# Out:
#      customer  customer_lifetime_value gender   income          st  \
# 0     RB50392                      NaN    NaN      0.0  Washington
# 1     QZ44356                6979.5359      F      0.0     Arizona
# 2     AI49188               12887.4317      F  48767.0      Nevada
# 3     WW63253                7645.8618      M      0.0  California
# 4     GA49547                5363.0765      M  36357.0  Washington
# ...       ...                      ...    ...      ...         ...
# 7065  LA72316                      NaN      M  71941.0  California
# 7066  PK87824                      NaN      F  21604.0  California
# 7067  TD14365                      NaN      M      0.0  California
# 7068  UP19263                      NaN      M  21941.0  California
# 7069  Y167826                      NaN      M      0.0  California
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                   1000.0                    1/0/00   Personal Auto
# ...

# %%
file4 = file4.drop(['number_of_open_complaints'], axis = 1)
file4
# Out:
#      customer  customer_lifetime_value gender   income          st  \
# 0     RB50392                      NaN    NaN      0.0  Washington
# 1     QZ44356                6979.5359      F      0.0     Arizona
# 2     AI49188               12887.4317      F  48767.0      Nevada
# 3     WW63253                7645.8618      M      0.0  California
# 4     GA49547                5363.0765      M  36357.0  Washington
# ...       ...                      ...    ...      ...         ...
# 7065  LA72316                      NaN      M  71941.0  California
# 7066  PK87824                      NaN      F  21604.0  California
# 7067  TD14365                      NaN      M      0.0  California
# 7068  UP19263                      NaN      M  21941.0  California
# 7069  Y167826                      NaN      M      0.0  California
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
file4['customer_lifetime_value'] = file4['customer_lifetime_value'].fillna(0)

# %%
file4
# Out:
#      customer  customer_lifetime_value gender   income          st  \
# 0     RB50392                   0.0000    NaN      0.0  Washington
# 1     QZ44356                6979.5359      F      0.0     Arizona
# 2     AI49188               12887.4317      F  48767.0      Nevada
# 3     WW63253                7645.8618      M      0.0  California
# 4     GA49547                5363.0765      M  36357.0  Washington
# ...       ...                      ...    ...      ...         ...
# 7065  LA72316                   0.0000      M  71941.0  California
# 7066  PK87824                   0.0000      F  21604.0  California
# 7067  TD14365                   0.0000      M      0.0  California
# 7068  UP19263                   0.0000      M  21941.0  California
# 7069  Y167826                   0.0000      M      0.0  California
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
file4.customer_lifetime_value.apply(int)
# Out:
# 0           0
# 1        6979
# 2       12887
# 3        7645
# 4        5363
#         ...
# 7065        0
# 7066        0
# 7067        0
# 7068        0
# 7069        0
# Name: customer_lifetime_value, Length: 12074, dtype: int64

# %%
file4
# Out:
#      customer  customer_lifetime_value gender   income          st  \
# 0     RB50392                   0.0000    NaN      0.0  Washington
# 1     QZ44356                6979.5359      F      0.0     Arizona
# 2     AI49188               12887.4317      F  48767.0      Nevada
# 3     WW63253                7645.8618      M      0.0  California
# 4     GA49547                5363.0765      M  36357.0  Washington
# ...       ...                      ...    ...      ...         ...
# 7065  LA72316                   0.0000      M  71941.0  California
# 7066  PK87824                   0.0000      F  21604.0  California
# 7067  TD14365                   0.0000      M      0.0  California
# 7068  UP19263                   0.0000      M  21941.0  California
# 7069  Y167826                   0.0000      M      0.0  California
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Check for duplicate rows in the data and remove if any.

file4.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7065    False
# 7066    False
# 7067    False
# 7068    False
# 7069    False
# Length: 12074, dtype: bool

# %%
file4.drop_duplicates()
# Out:
#      customer  customer_lifetime_value gender   income          st  \
# 0     RB50392                   0.0000    NaN      0.0  Washington
# 1     QZ44356                6979.5359      F      0.0     Arizona
# 2     AI49188               12887.4317      F  48767.0      Nevada
# 3     WW63253                7645.8618      M      0.0  California
# 4     GA49547                5363.0765      M  36357.0  Washington
# ...       ...                      ...    ...      ...         ...
# 7065  LA72316                   0.0000      M  71941.0  California
# 7066  PK87824                   0.0000      F  21604.0  California
# 7067  TD14365                   0.0000      M      0.0  California
# 7068  UP19263                   0.0000      M  21941.0  California
# 7069  Y167826                   0.0000      M      0.0  California
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
#Filter out the data for customers who have an income of 0 or less.
condition = (file4['income'] == 0)
file4[condition]
# Out:
#      customer  customer_lifetime_value gender  income          st  \
# 0     RB50392                   0.0000    NaN     0.0  Washington
# 1     QZ44356                6979.5359      F     0.0     Arizona
# 3     WW63253                7645.8618      M     0.0  California
# 7     CF85061                7216.1003      M     0.0     Arizona
# 10    SX51350                4738.9920      M     0.0  California
# ...       ...                      ...    ...     ...         ...
# 7059  WZ45103                   0.0000      F     0.0  California
# 7061  RX91025                   0.0000      M     0.0  California
# 7062  AC13887                   0.0000      M     0.0  California
# 7067  TD14365                   0.0000      M     0.0  California
# 7069  Y167826                   0.0000      M     0.0  California
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
